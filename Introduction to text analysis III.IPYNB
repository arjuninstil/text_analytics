# %% [markdown]
# ### Tokenization part II ###

# %% [markdown]
# ** working with text **

# %% [markdown]
# In computing, a comma-separated values (CSV) file stores tabular data (numbers and text) in plain text. Each line of the file is a data record. Each record consists of one or more fields, separated by commas. The use of the comma as a field separator is the source of the name for this file format.
#
# The CSV file format is not standardized. The basic idea of separating fields with a comma is clear, but that idea gets complicated when the field data may also contain commas or even embedded line-breaks. CSV implementations may not handle such field data, or they may use quotation marks to surround the field. Quotation does not solve everything: some fields may need embedded quotation marks, so a CSV implementation may include escape characters or escape sequences.
#
# In addition, the term "CSV" also denotes some closely related delimiter-separated formats that use different field delimiters. These include tab-separated values and space-separated values. A delimiter that is not present in the field data (such as tab) keeps the format parsing simple. These alternate delimiter-separated files are often even given a .csv extension despite the use of a non-comma field separator. This loose terminology can cause problems in data exchange. Many applications that accept CSV files have options to select the delimiter character and the quotation character.

# %%
text = """In computing, a comma-separated values (CSV) file stores tabular data (numbers and text) in plain text. Each line of the file is a data record. Each record consists of one or more fields, separated by commas. The use of the comma as a field separator is the source of the name for this file format.

The CSV file format is not standardized. The basic idea of separating fields with a comma is clear, but that idea gets complicated when the field data may also contain commas or even embedded line-breaks. CSV implementations may not handle such field data, or they may use quotation marks to surround the field. Quotation does not solve everything: some fields may need embedded quotation marks, so a CSV implementation may include escape characters or escape sequences.

In addition, the term "CSV" also denotes some closely related delimiter-separated formats that use different field delimiters. These include tab-separated values and space-separated values. A delimiter that is not present in the field data (such as tab) keeps the format parsing simple. These alternate delimiter-separated files are often even given a .csv extension despite the use of a non-comma field separator. This loose terminology can cause problems in data exchange. Many applications that accept CSV files have options to select the delimiter character and the quotation character.

"""

# %% [markdown]
# Extracting sentences ? extracting paragraphs ?

# %%
paragraphs = text.split("\n")

print(paragraphs[0])
# Out:
# In computing, a comma-separated values (CSV) file stores tabular data (numbers and text) in plain text. Each line of the file is a data record. Each record consists of one or more fields, separated by commas. The use of the comma as a field separator is the source of the name for this file format.

# %%
print(paragraphs[1]) ## why is empty ?

# %%
paragraphs = text.split("\n\n") ## solution double \n\n ...

print(paragraphs[1])
# Out:
# The CSV file format is not standardized. The basic idea of separating fields with a comma is clear, but that idea gets complicated when the field data may also contain commas or even embedded line-breaks. CSV implementations may not handle such field data, or they may use quotation marks to surround the field. Quotation does not solve everything: some fields may need embedded quotation marks, so a CSV implementation may include escape characters or escape sequences.

# %% [markdown]
# ** a better solution **

# %%
import re

sp = re.split('\n+', text) ## splitting using regular expressions
print(sp)
# Out:
# ['In computing, a comma-separated values (CSV) file stores tabular data (numbers and text) in plain text. Each line of the file is a data record. Each record consists of one or more fields, separated by commas. The use of the comma as a field separator is the source of the name for this file format.', 'The CSV file format is not standardized. The basic idea of separating fields with a comma is clear, but that idea gets complicated when the field data may also contain commas or even embedded line-breaks. CSV implementations may not handle such field data, or they may use quotation marks to surround the field. Quotation does not solve everything: some fields may need embedded quotation marks, so a CSV implementation may include escape characters or escape sequences.', 'In addition, the term "CSV" also denotes some closely related delimiter-separated formats that use different field delimiters. These include tab-separated values and space-separated values. A delimiter that is not present in the field data (such as tab) keeps the format parsing simple. These alternate delimiter-separated files are often even given a .csv extension despite the use of a non-comma field separator. This loose terminology can cause problems in data exchange. Many applications that accept CSV files have options to select the delimiter character and the quotation character.', '']

# %%
help(re)
# Out:
# Help on module re:
#
# NAME
#     re - Support for regular expressions (RE).
#
# MODULE REFERENCE
#     https://docs.python.org/3.5/library/re
#
#     The following documentation is automatically generated from the Python
#     source files.  It may be incomplete, incorrect or include features that
#     are considered implementation detail and may vary between Python
#     implementations.  When in doubt, consult the module reference at the
#     location listed above.
#
# DESCRIPTION
#     This module provides regular expression matching operations similar to
#     those found in Perl.  It supports both 8-bit and Unicode strings; both
#     the pattern and the strings being processed can contain null bytes and
#     characters outside the US ASCII range.
#
#     Regular expressions can contain both special and ordinary characters.
#     Most ordinary characters, like "A", "a", or "0", are the simplest
#     regular expressions; they simply match themselves.  You can
#     concatenate ordinary characters, so last matches the string 'last'.
#
#     The special characters are:
#         "."      Matches any character except a newline.
#         "^"      Matches the start of the string.
#         "$"      Matches the end of the string or just before the newline at
#                  the end of the string.
#         "*"      Matches 0 or more (greedy) repetitions of the preceding RE.
#                  Greedy means that it will match as many repetitions as possible.
#         "+"      Matches 1 or more (greedy) repetitions of the preceding RE.
#         "?"      Matches 0 or 1 (greedy) of the preceding RE.
#         *?,+?,?? Non-greedy versions of the previous three special characters.
#         {m,n}    Matches from m to n repetitions of the preceding RE.
#         {m,n}?   Non-greedy version of the above.
#         "\\"     Either escapes special characters or signals a special sequence.
#         []       Indicates a set of characters.
#                  A "^" as the first character indicates a complementing set.
#         "|"      A|B, creates an RE that will match either A or B.
#         (...)    Matches the RE inside the parentheses.
#                  The contents can be retrieved or matched later in the string.
#         (?aiLmsux) Set the A, I, L, M, S, U, or X flag for the RE (see below).
#         (?:...)  Non-grouping version of regular parentheses.
#         (?P<name>...) The substring matched by the group is accessible by name.
#         (?P=name)     Matches the text matched earlier by the group named name.
#         (?#...)  A comment; ignored.
#         (?=...)  Matches if ... matches next, but doesn't consume the string.
#         (?!...)  Matches if ... doesn't match next.
#         (?<=...) Matches if preceded by ... (must be fixed length).
#         (?<!...) Matches if not preceded by ... (must be fixed length).
#         (?(id/name)yes|no) Matches yes pattern if the group with id/name matched,
#                            the (optional) no pattern otherwise.
#
#     The special sequences consist of "\\" and a character from the list
#     below.  If the ordinary character is not on the list, then the
#     resulting RE will match the second character.
#         \number  Matches the contents of the group of the same number.
#         \A       Matches only at the start of the string.
#         \Z       Matches only at the end of the string.
#         \b       Matches the empty string, but only at the start or end of a word.
#         \B       Matches the empty string, but not at the start or end of a word.
#         \d       Matches any decimal digit; equivalent to the set [0-9] in
#                  bytes patterns or string patterns with the ASCII flag.
#                  In string patterns without the ASCII flag, it will match the whole
#                  range of Unicode digits.
#         \D       Matches any non-digit character; equivalent to [^\d].
#         \s       Matches any whitespace character; equivalent to [ \t\n\r\f\v] in
#                  bytes patterns or string patterns with the ASCII flag.
#                  In string patterns without the ASCII flag, it will match the whole
#                  range of Unicode whitespace characters.
#         \S       Matches any non-whitespace character; equivalent to [^\s].
#         \w       Matches any alphanumeric character; equivalent to [a-zA-Z0-9_]
#                  in bytes patterns or string patterns with the ASCII flag.
#                  In string patterns without the ASCII flag, it will match the
#                  range of Unicode alphanumeric characters (letters plus digits
#                  plus underscore).
#                  With LOCALE, it will match the set [0-9_] plus characters defined
#                  as letters for the current locale.
#         \W       Matches the complement of \w.
#         \\       Matches a literal backslash.
#
#     This module exports the following functions:
#         match     Match a regular expression pattern to the beginning of a string.
#         fullmatch Match a regular expression pattern to all of a string.
#         search    Search a string for the presence of a pattern.
#         sub       Substitute occurrences of a pattern found in a string.
#         subn      Same as sub, but also return the number of substitutions made.
#         split     Split a string by the occurrences of a pattern.
#         findall   Find all occurrences of a pattern in a string.
#         finditer  Return an iterator yielding a match object for each match.
#         compile   Compile a pattern into a RegexObject.
#         purge     Clear the regular expression cache.
#         escape    Backslash all non-alphanumerics in a string.
#
#     Some of the functions in this module takes flags as optional parameters:
#         A  ASCII       For string patterns, make \w, \W, \b, \B, \d, \D
#                        match the corresponding ASCII character categories
#                        (rather than the whole Unicode categories, which is the
#                        default).
#                        For bytes patterns, this flag is the only available
#                        behaviour and needn't be specified.
#         I  IGNORECASE  Perform case-insensitive matching.
#         L  LOCALE      Make \w, \W, \b, \B, dependent on the current locale.
#         M  MULTILINE   "^" matches the beginning of lines (after a newline)
#                        as well as the string.
#                        "$" matches the end of lines (before a newline) as well
#                        as the end of the string.
#         S  DOTALL      "." matches any character at all, including the newline.
#         X  VERBOSE     Ignore whitespace and comments for nicer looking RE's.
#         U  UNICODE     For compatibility only. Ignored for string patterns (it
#                        is the default), and forbidden for bytes patterns.
#
#     This module also defines an exception 'error'.
#
# CLASSES
#     builtins.Exception(builtins.BaseException)
#         sre_constants.error
#
#     class error(builtins.Exception)
#      |  Common base class for all non-exit exceptions.
#      |
#      |  Method resolution order:
#      |      error
#      |      builtins.Exception
#      |      builtins.BaseException
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, msg, pattern=None, pos=None)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from builtins.Exception:
#      |
#      |  __new__(*args, **kwargs) from builtins.type
#      |      Create and return a new object.  See help(type) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from builtins.BaseException:
#      |
#      |  __delattr__(self, name, /)
#      |      Implement delattr(self, name).
#      |
#      |  __getattribute__(self, name, /)
#      |      Return getattr(self, name).
#      |
#      |  __reduce__(...)
#      |      helper for pickle
#      |
#      |  __repr__(self, /)
#      |      Return repr(self).
#      |
#      |  __setattr__(self, name, value, /)
#      |      Implement setattr(self, name, value).
#      |
#      |  __setstate__(...)
#      |
#      |  __str__(self, /)
#      |      Return str(self).
#      |
#      |  with_traceback(...)
#      |      Exception.with_traceback(tb) --
#      |      set self.__traceback__ to tb and return self.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from builtins.BaseException:
#      |
#      |  __cause__
#      |      exception cause
#      |
#      |  __context__
#      |      exception context
#      |
#      |  __dict__
#      |
#      |  __suppress_context__
#      |
#      |  __traceback__
#      |
#      |  args
#
# FUNCTIONS
#     compile(pattern, flags=0)
#         Compile a regular expression pattern, returning a pattern object.
#
#     escape(pattern)
#         Escape all the characters in pattern except ASCII letters, numbers and '_'.
#
#     findall(pattern, string, flags=0)
#         Return a list of all non-overlapping matches in the string.
#
#         If one or more capturing groups are present in the pattern, return
#         a list of groups; this will be a list of tuples if the pattern
#         has more than one group.
#
#         Empty matches are included in the result.
#
#     finditer(pattern, string, flags=0)
#         Return an iterator over all non-overlapping matches in the
#         string.  For each match, the iterator returns a match object.
#
#         Empty matches are included in the result.
#
#     fullmatch(pattern, string, flags=0)
#         Try to apply the pattern to all of the string, returning
#         a match object, or None if no match was found.
#
#     match(pattern, string, flags=0)
#         Try to apply the pattern at the start of the string, returning
#         a match object, or None if no match was found.
#
#     purge()
#         Clear the regular expression caches
#
#     search(pattern, string, flags=0)
#         Scan through string looking for a match to the pattern, returning
#         a match object, or None if no match was found.
#
#     split(pattern, string, maxsplit=0, flags=0)
#         Split the source string by the occurrences of the pattern,
#         returning a list containing the resulting substrings.  If
#         capturing parentheses are used in pattern, then the text of all
#         groups in the pattern are also returned as part of the resulting
#         list.  If maxsplit is nonzero, at most maxsplit splits occur,
#         and the remainder of the string is returned as the final element
#         of the list.
#
#     sub(pattern, repl, string, count=0, flags=0)
#         Return the string obtained by replacing the leftmost
#         non-overlapping occurrences of the pattern in string by the
#         replacement repl.  repl can be either a string or a callable;
#         if a string, backslash escapes in it are processed.  If it is
#         a callable, it's passed the match object and must return
#         a replacement string to be used.
#
#     subn(pattern, repl, string, count=0, flags=0)
#         Return a 2-tuple containing (new_string, number).
#         new_string is the string obtained by replacing the leftmost
#         non-overlapping occurrences of the pattern in the source
#         string by the replacement repl.  number is the number of
#         substitutions that were made. repl can be either a string or a
#         callable; if a string, backslash escapes in it are processed.
#         If it is a callable, it's passed the match object and must
#         return a replacement string to be used.
#
#     template(pattern, flags=0)
#         Compile a template pattern, returning a pattern object
#
# DATA
#     A = 256
#     ASCII = 256
#     DOTALL = 16
#     I = 2
#     IGNORECASE = 2
#     L = 4
#     LOCALE = 4
#     M = 8
#     MULTILINE = 8
#     S = 16
#     U = 32
#     UNICODE = 32
#     VERBOSE = 64
#     X = 64
#     __all__ = ['match', 'fullmatch', 'search', 'sub', 'subn', 'split', 'fi...
#
# VERSION
#     2.2.1
#
# FILE
#     /usr/lib/python3.5/re.py

# %% [markdown]
# ** splitting sentences simple way **

# %%
for s in sp:
    sentences = s.split(".")
    print(sentences)
    break
# Out:
# ['In computing, a comma-separated values (CSV) file stores tabular data (numbers and text) in plain text', ' Each line of the file is a data record', ' Each record consists of one or more fields, separated by commas', ' The use of the comma as a field separator is the source of the name for this file format', '']

# %% [markdown]
# ## tokenization professional way ##

# %% [markdown]
# ** using NLTK natural language toolkig **

# %%
import nltk 
from nltk.tokenize import sent_tokenize

# %%
"punkt", "stopwords", "twitter_samples"

# %%
nltk.download('twitter_samples')
# Out:
# [nltk_data] Downloading package twitter_samples to
# [nltk_data]     /home/mick/nltk_data...
# [nltk_data]   Package twitter_samples is already up-to-date!
# True

# %% [markdown]
# ** to use the sentence tokenizer we need an english corpus called "punkt" with nltk.download()**

# %%
sentences = sent_tokenize(text)

# %%
for s in sentences:
    print(s)
# Out:
# In computing, a comma-separated values (CSV) file stores tabular data (numbers and text) in plain text.
# Each line of the file is a data record.
# Each record consists of one or more fields, separated by commas.
# The use of the comma as a field separator is the source of the name for this file format.
# The CSV file format is not standardized.
# The basic idea of separating fields with a comma is clear, but that idea gets complicated when the field data may also contain commas or even embedded line-breaks.
# CSV implementations may not handle such field data, or they may use quotation marks to surround the field.
# Quotation does not solve everything: some fields may need embedded quotation marks, so a CSV implementation may include escape characters or escape sequences.
# In addition, the term "CSV" also denotes some closely related delimiter-separated formats that use different field delimiters.
# These include tab-separated values and space-separated values.
# A delimiter that is not present in the field data (such as tab) keeps the format parsing simple.
# These alternate delimiter-separated files are often even given a .csv extension despite the use of a non-comma field separator.
# This loose terminology can cause problems in data exchange.
# Many applications that accept CSV files have options to select the delimiter character and the quotation character.

# %%
complex_case = "This is a sentence. In this one there is an acronym N.A.S.A to treat like a sentence."
sentences = sent_tokenize(complex_case)

# %%
for c in sentences:
    print(c)
# Out:
# This is a sentence.
# In this one there is an acronym N.A.S.A to treat like a sentence.

# %% [markdown]
# ** tokenizing words **

# %%
from nltk.tokenize import word_tokenize

# %%
tokens = word_tokenize(text)

# %%
print(tokens)
# Out:
# ['In', 'computing', ',', 'a', 'comma-separated', 'values', '(', 'CSV', ')', 'file', 'stores', 'tabular', 'data', '(', 'numbers', 'and', 'text', ')', 'in', 'plain', 'text', '.', 'Each', 'line', 'of', 'the', 'file', 'is', 'a', 'data', 'record', '.', 'Each', 'record', 'consists', 'of', 'one', 'or', 'more', 'fields', ',', 'separated', 'by', 'commas', '.', 'The', 'use', 'of', 'the', 'comma', 'as', 'a', 'field', 'separator', 'is', 'the', 'source', 'of', 'the', 'name', 'for', 'this', 'file', 'format', '.', 'The', 'CSV', 'file', 'format', 'is', 'not', 'standardized', '.', 'The', 'basic', 'idea', 'of', 'separating', 'fields', 'with', 'a', 'comma', 'is', 'clear', ',', 'but', 'that', 'idea', 'gets', 'complicated', 'when', 'the', 'field', 'data', 'may', 'also', 'contain', 'commas', 'or', 'even', 'embedded', 'line-breaks', '.', 'CSV', 'implementations', 'may', 'not', 'handle', 'such', 'field', 'data', ',', 'or', 'they', 'may', 'use', 'quotation', 'marks', 'to', 'surround', 'the', 'field', '.', 'Quotation', 'does', 'not', 'solve', 'everything', ':', 'some', 'fields', 'may', 'need', 'embedded', 'quotation', 'marks', ',', 'so', 'a', 'CSV', 'implementation', 'may', 'include', 'escape', 'characters', 'or', 'escape', 'sequences', '.', 'In', 'addition', ',', 'the', 'term', '``', 'CSV', "''", 'also', 'denotes', 'some', 'closely', 'related', 'delimiter-separated', 'formats', 'that', 'use', 'different', 'field', 'delimiters', '.', 'These', 'include', 'tab-separated', 'values', 'and', 'space-separated', 'values', '.', 'A', 'delimiter', 'that', 'is', 'not', 'present', 'in', 'the', 'field', 'data', '(', 'such', 'as', 'tab', ')', 'keeps', 'the', 'format', 'parsing', 'simple', '.', 'These', 'alternate', 'delimiter-separated', 'files', 'are', 'often', 'even', 'given', 'a', '.csv', 'extension', 'despite', 'the', 'use', 'of', 'a', 'non-comma', 'field', 'separator', '.', 'This', 'loose', 'terminology', 'can', 'cause', 'problems', 'in', 'data', 'exchange', '.', 'Many', 'applications', 'that', 'accept', 'CSV', 'files', 'have', 'options', 'to', 'select', 'the', 'delimiter', 'character', 'and', 'the', 'quotation', 'character', '.']

# %% [markdown]
# ** special tokenizer **

# %%
from nltk.tokenize import TweetTokenizer

s0 = "This is a cooool #dummysmiley: :-) :-P <3 and some arrows < > -> <--"

model = TweetTokenizer()

tokens = model.tokenize(s0)

print(tokens)
# Out:
# ['This', 'is', 'a', 'cooool', '#dummysmiley', ':', ':-)', ':-P', '<3', 'and', 'some', 'arrows', '<', '>', '->', '<--']

# %% [markdown]
# notice how the tokenizer treated the emoticons

# %%
import json
from nltk.tokenize import TweetTokenizer

# %%
file_location = "/home/mick/nltk_data/corpora/twitter_samples/negative_tweets.json"

# %%
model = TweetTokenizer()

# %% [raw]
# allTweets = []
# allTokens = []
#
# for line in open(file_location,"r"):
#     js = json.loads(line.rstrip())
#     tweet = js['text']
#     tokens = model.tokenize(tweet)
#     print(tokens)
#     allTokens.append(tokens)
#     allTweets.append(js['text'])

# %%
countWords = {}
howmanywords = set()
j = 0
for t in allTokens:
    #print(t)
    for word in t:
        #print(word)
        howmanywords.add(word)
        if(j % 10000 == 0):
            print(len(howmanywords))
        if(word in countWords ):
            countWords[word] = countWords[word] + 1
        else:
            countWords[word] =  1
        j  = j  +1 ## j += 1
# Out:
# 1
# 3251
# 5372
# 7069
# 8725
# 10467
# 12013

# %%
import pandas as pd

# %%
df = pd.DataFrame.from_dict(countWords,orient="index")

# %%
df.sort_values(by=0,ascending = False).head(100)
# Out:
#                   0
# :(             4585
# I              1587
# (              1180
# .              1092
# to             1068
# the             846
# !               831
# ,               734
# you             660
# ?               644
# my              629
# a               627
# i               620
# and             614
# me              524
# :-(             501
# so              466
# is              456
# it              449
# in              421
# for             391
# but             384
# of              352
# ...             332
# have            306
# on              297
# I'm             295
# this            270
# not             268
# that            263
# ...             ...
# sorry           111
# when            110
# been            110
# ..              108
# they            106
# still           104
# &               102
# FOLLOWED        102
# about           100
# today           100
# what             99
# see              99
# much             96
# got              94
# @justinbieber    93
# im               93
# My               91
# day              91
# feel             91
# work             89
# from             89
# will             89
# am               88
# wanna            86
# again            85
# if               84
# going            83
# there            83
# good             82
# need             81
#
# [100 rows x 1 columns]

# %%
for word,counts in countWords.items():
    print(word,counts)
# Out:
# 💓 2
# @ApplePieQueen_ 1
# http://t.co/taVMCz37E7 1
# visiting 1
# Please 21
# @xBethanyOystonx 1
# Until 1
# http://t.co/r5fMnyWyUf 1
# @LucasUpton 1
# ervin 1
# Caroline 1
# Ashraf 1
# #MUFC 1
# #nudes 3
# waaah 1
# #PitchWars 1
# filming 2
# http://t.co/UR8ZwngzJZ 1
# #hornykik 17
# Nowt 1
# #Kadhafi 2
# Utd 2
# thumb 1
# spooky 1
# 32 1
# @1q4h_ 1
# Ce 1
# budget 1
# UNEXPECT 1
# oops 2
# argument 1
# pero 1
# QUIT 1
# PHANTASY 1
# crazy 7
# pas 1
# CANNOT 1
# trash 2
# @teamkins 1
# scarf 1
# Waking 1
# http://t.co/iL86HQ4Uyh 1
# Subdivision 1
# havent 9
# hairs 1
# @Janettaras 1
# townssssss 1
# Toll 1
# listening 4
# @Marx_Envy 2
# @tanginarrymo 1
# Emma 1
# @bbcweather 1
# Nor 1
# Sry 1
# Nerve 1
# nanaman 1
# @rvirenee_ 1
# bestfriends 1
# getaway 1
# NEMEN 1
# choregrapher 1
# viber 1
# BIOMES 1
# 🍹 3
# need 81
# babyy 1
# @haestarxx 1
# @HUNCH0 1
# @LHBF7F 1
# @thetrin 1
# agessss 1
# samjha 1
# Lost 1
# charts 2
# 633 1
# BROOKE 1
# @josselynramos01 1
# saturday 4
# yet 32
# dormmates 1
# critical 1
# Dear 1
# lasting 1
# honestly 3
# Dard 1
# 23 2
# babies 4
# @GABRlEIIE 1
# photo 6
# dissappeared 1
# Oh 33
# something 26
# nation 2
# ised 1
# Royal 1
# dongwoo 1
# folder 1
# suspect 1
# books 3
# injured 5
# @bubblegumcam 1
# @blvsamx 1
# ebook 1
# kit 5
# Haven't 3
# lowest 1
# intention 1
# @ImKhweziN 2
# solvo 1
# tunaita 1
# lmfaooooo 1
# @clawdeeeeya 1
# stolen 2
# rip 5
# vishwas 1
# Zara 1
# SEE 6
# TODAY 2
# unprepared 1
# power 5
# Taking 1
# bcz 1
# facking 1
# @Patrickcf26 1
# eric 1
# safaa 1
# modern 1
# desserts 1
# #webcam 2
# ALBUM 1
# @UrsulaWJ 1
# boy 7
# bar 1
# traffic 5
# Sandra 2
# @svthoshipit 1
# http://t.co/93Z6WOVOs9 1
# 349 1
# Haiqal 1
# offended 1
# Honestly 1
# @BannonAmanda 1
# silently 1
# Awhh 1
# right 46
# relief 1
# @demiroberts_ 1
# lies 2
# infrastructure 1
# Child 1
# agh 1
# @walls 2
# Sepanx 1
# uh 4
# @ClaireClaire05 1
# travelling 2
# Things 2
# eritation 1
# genuinely 1
# 11.00 1
# | 8
# well 43
# our 46
# @ArunbuddyAP 1
# 4:20 1
# usey 2
# ✨ 1
# ladder 2
# saddest 2
# http://t.co/gXI974Xj63"saoloh 1
# dallas 1
# supreme 1
# Disability 1
# https://t.co/hQ4y4FKniZ 1
# huhuh 1
# unfair 6
# @MaayanGean 1
# Joc 1
# WHO 2
# question 3
# @EmmaLK 2
# @versacelopez 1
# @tommophoebe 1
# except 3
# tan 2
# himseek 1
# Ok 3
# #getthescoop 1
# 1/5 1
# Analyst 1
# @GHSDuldulao 1
# remind 1
# MIGHT 1
# pass 10
# @vinylify 1
# #akua 1
# po 1
# stars 2
# future 2
# NYC 2
# together 7
# Bravo 1
# regularly 2
# was 232
# Poorly 1
# @kylaaareese 1
# Petrofac 1
# preform 1
# @brittleyouth 1
# ng 3
# gurly 1
# 6/7 1
# States 1
# jollies 1
# @jakeblackah 1
# Antonio 1
# Freaking 2
# table 2
# walay 1
# load 7
# 335 1
# @LoseThe_Battle 1
# DONG 1
# gua 1
# srsly 5
# they'd 2
# elbow 1
# https://t.co/tTWEtt5GEP 1
# abudhabi 1
# @FemaleBloggerRT 1
# @_kydd_que 1
# doggy 1
# @Mr_FRML 1
# @CurlyxStyls 1
# ATTENTION 1
# entry 2
# misss 2
# @fvvxkk 1
# plug 2
# son 1
# chains 1
# @lewiismynewt 1
# everywhere 6
# grew 2
# homo 2
# @CRIMINALMOX 1
# exercise 1
# akong 1
# PROUD 2
# @DeEstrellados 1
# #SleepingWithSirens 1
# @bethisbest01 1
# signature 1
# wife 1
# ZOO 1
# loading 1
# Taxonomic 1
# Reality 1
# pleaseeeee 2
# MINHYUKS 1
# SOMEONE 3
# messy 1
# definitely 1
# @CourtneyR_Green 1
# @KingsDecor 1
# rider 1
# beard 1
# @KOBprod 1
# @jackgilinsky 4
# @selenagomez 8
# tooooooo 1
# till 8
# र 2
# cmc 1
# lounge 1
# anesthesia 1
# @louloubarton81 1
# Deputy 1
# hopeful 1
# #athabasca 1
# Moodboster 1
# #에이핑크 3
# #CaesarsPalace 1
# BO3 1
# https://t.co/hfGyVJQ5RA 1
# Louisiana 2
# hold 7
# put 13
# WINNERS 1
# clash 2
# http://t.co/T8pqZuLaEx 1
# 333 4
# Igbo 1
# uwesiti 1
# Answer 1
# Majhwar 1
# @koreanplease 1
# funny 6
# st 2
# @HanaaGhzlli 1
# icon 1
# those 28
# hahah 4
# daughter 1
# @StarPlus 1
# Alex's 1
# jump 1
# skype 1
# alright 3
# BOYS 1
# plz 4
# miss 212
# @AppleMusic 1
# haiz 1
# @CRMDKS 1
# S2E12 1
# Ocean 3
# Millie 1
# Sunday 5
# Emotionally 1
# appropriate 1
# idea 10
# @denniselazaro 1
# TIRED 2
# socks 6
# Maternity 1
# talks 2
# http://t.co/dl1AgJykBH 1
# her 60
# benedictervention 1
# tweet 18
# followback 4
# @EMPERYtech 1
# Eyyah 1
# desperate 2
# bus 4
# @ohkaibaeks 1
# @SlXSTRINGS 2
# Yes 15
# #TiredAsHell 1
# centralise 1
# truly 4
# 1190 1
# @pieterebersohn 1
# @nayybear 2
# repair 3
# crash 2
# Fack 1
# 😂 24
# paid 8
# Im 21
# @BroderickDamien 1
# @RookieKE 1
# 3.4 1
# rides 1
# fruit 1
# WHITE 1
# Unfamiliar 1
# daming 1
# ID 2
# http://t.co/zWreWycNrf 1
# #gay 2
# apply 1
# clips 1
# vocals 1
# http://t.co/tChmTf8om4 1
# https://t.co/wdETpUIyOZ 1
# ps 2
# SPAM 1
# @PUKENIHORAN 1
# @YerifeRV 1
# contemporary 1
# EMEGED 1
# remedy 1
# engg 1
# kanina 2
# part 9
# City 6
# http://t.co/IjVWwO32eO 1
# thwarting 1
# @MonsterxStitch 1
# @ThapeloMokz 1
# @Childcareisfun 1
# @SwagOnChristian 1
# abandoned 1
# hearess 1
# kaylas 1
# Agh 1
# @heineckrr 1
# @gfcakelover 1
# @Sam_Ardi 1
# i'll 11
# HATE 1
# 21 1
# Sengenza 1
# announce 2
# @DareToAttar 1
# okies 1
# https://t.co/LGQRwfFTiO 1
# iwantin 1
# promethazine 1
# headache 7
# grandad 1
# @jabongindia 1
# ZONE 1
# gyu 3
# 800 1
# SEO 1
# sessions 1
# @jasmine_chantay 1
# empty 3
# team 14
# @norm 1
# #bored 1
# rounds 1
# Cant 6
# rizal 1
# rebound 1
# socket 1
# Naomi 1
# #FaceTime 2
# nxt 1
# Double 1
# eldest 1
# Overly 1
# LOOKED 1
# do 156
# trip 9
# 111 1
# @chattsss 2
# fineandyu 1
# SCREENSHOTTING 1
# OKAY 1
# songs 5
# @infispirit_ 1
# @thevinnythepooh 2
# @WWESuperCard_Ar 1
# delighted 1
# Feels 2
# Bank 2
# 😚 4
# razzist 1
# @tylerftirwin 1
# @ArianaGrande 2
# host 1
# isnt 7
# buff 1
# le 3
# maccies 1
# @itsdemigdr 1
# J 1
# Stay 1
# song 20
# #disappointed 1
# Laguna 1
# carry 1
# hannah 1
# Pigs 1
# Wow 1
# headphones 1
# @crunchy_mummy 1
# 0-2 1
# kapan 1
# dey 2
# hanaaaa 1
# @Jae0409 1
# city 4
# Niaaaaaaaaaaaaaaaaaaaaaaaaaaa 1
# @madjade24 1
# acne 2
# http://t.co/waZjxi7TQa 1
# http://t.co/9xWKegCy6W 1
# HUH 1
# irene 1
# @niveditabasu 1
# Soul 2
# history 2
# @sophielouuu_ 1
# @Starlight_Sarah 1
# nicki 1
# #phandroid 1
# @pamupamorada08 1
# policy 1
# cebu 1
# December 1
# head 19
# tiring 4
# Old 1
# 1.300 1
# @QShawtymane 1
# error 2
# 20th 1
# potter 1
# delivered 2
# http://t.co/724BGj38Hq 1
# respond 1
# #NotAnApology 3
# @ErisLovesMovies 1
# @StaMar999 1
# 💒 1
# Dorm 1
# THOUGHT 1
# fah 1
# lord 1
# c 4
# cock 1
# @BeingJahirShah 1
# @MOONEMOJAI 1
# animal 2
# http://t.co/EXV5MoItcE 1
# @KianLawley 2
# 💎 1
# Sucks 3
# @natalieegiselle 1
# cunt 1
# 823 1
# @sabal_abla 2
# mama 1
# @UdotV 1
# gn 1
# http://t.co/7pJJ9q5v7z 1
# @saad_my_life 1
# no-no 1
# @vlamhlongovic 1
# https://t.co/q4ue6MrFS9 1
# TWICE 1
# GREAT 2
# familiar 1
# @Emeraldere 2
# tummy 5
# sweet 7
# GONE 2
# @SMARTCares 1
# please 122
# aren't 7
# slathered 1
# Danny 1
# http://t.co/AcXikXwfcI 1
# Download 1
# suits 1
# wt 1
# unlike 2
# Geneva 1
# @Sibulela_M 2
# @chatlas 1
# https://t.co/VVLTlmOsQ0 1
# maa 1
# Looks 7
# @swelcome 1
# again 85
# 💙 1
# bandar 1
# may 13
# Discovery 1
# The 50
# #weloveyounamjoon 1
# @MrCrump3ts 1
# belieb 1
# Weekend 1
# . 1092
# #London 1
# @YseIcedTey 1
# steel 1
# GOOD 1
# http://t.co/XysuSB0fxK 1
# payhour 1
# @daseonjwi 1
# http://t.co/MT1tFymZGU 4
# jumpa 1
# wifi 3
# AWWWWWWWW 1
# law 3
# MONEY 1
# atm 1
# dont 47
# linguist 1
# ARE 6
# @PureBexcellence 1
# @eksobyvnb 1
# https://t.co/3qH5rrf0xs 1
# rands 1
# rest 18
# lock 1
# ifsc 1
# player 1
# chickmt 1
# #BRINGMETHEHORIZON 1
# @omgNova 1
# @brittannie_13 1
# @Cath_Kidston 1
# wail 1
# want 201
# @abrianaaaa__ 1
# infinite 3
# Cat 1
# https://t.co/T1OVu6r9wT 1
# @biabistrot 1
# hiondsheings 1
# whatsoever 2
# Angie 1
# boyirl 1
# @S0LV0 2
# @mrytrzi 1
# @heyitsCysee 1
# @douxVictoriammy 1
# L 1
# MANY 1
# rewert 1
# pala 1
# ect 1
# @TanyaBurr 1
# @KBedders 1
# http://t.co/Z0dePj5knU 1
# @princessviki13 1
# http://t.co/oKR3mwS4jm 1
# emma 1
# Thank 7
# massive 4
# @benrwms 1
# @juonghwa 1
# hotwheels 1
# b4 1
# 41 1
# @myywoohyun 1
# reactions 1
# carmen 1
# http://t.co/T8O7X2aRTm 1
# @Aussie_Legend 1
# #sexysasunday 2
# Monday 6
# 😄 1
# @ErnestLozoya 1
# @JuzzyftMahone 1
# metal 1
# piano 2
# teteh 1
# @AprilXyloto 1
# delete 3
# ＭＥ 35
# Your 3
# @AlejoDoe 1
# Jouch 1
# @satabengdagat 1
# AHH 1
# TF 1
# DAMN 2
# travel 5
# abs 3
# Merlin 1
# Nak 1
# @robertsammons 1
# Salam 1
# tell 20
# #photooftheday 2
# legit 1
# @kiwivickiBSc 1
# KILLED 1
# @crybassist 1
# lq 1
# DONT 3
# neck 1
# News 2
# @misslolitalove 1
# families 1
# @xcliffordpizza 1
# quick 5
# frightening 1
# Sir 1
# http://t.co/mQrHl6Guv0 1
# it 449
# opener 1
# se 2
# sigeg 1
# GH 1
# guinea 1
# @Argos_Online 1
# officially 2
# cutting 1
# dus 1
# accepted 1
# Leeds 5
# strawberry 1
# tickets 8
# follows 1
# Don 1
# UNFAIR 1
# bruised 1
# will 89
# yeah 28
# bein 1
# torturing 1
# 😉 1
# duty 1
# DW 1
# @sainsburys 3
# @fantasticpru 1
# @sophiabxsh 1
# kitchen 3
# tanto 1
# puppy 1
# @1994sdork 1
# comments 3
# natural 1
# @desiboy34783 1
# Quuuuuuee 1
# b-but 1
# weak 2
# spinny 1
# 💔 3
# @natishlouise 1
# @to_kazanaki 1
# Don't 16
# https://t.co/sZemQfSZWx 1
# @nuriaagonzalez 1
# swan 1
# w'end 1
# ystrday 1
# ❤ 21
# fluent 1
# @tackdriver56 1
# Most 1
# inch 1
# @justinbieber 93
# @my_nameis_dan 1
# commission 1
# refurbished 1
# 72 4
# din 1
# waiting 12
# @i_am_mill_i_am 1
# kinda 9
# spend 7
# go 131
# about 100
# sulk 1
# @Mvusi_ 1
# FROM 2
# shooting 3
# AS 3
# Ufffff 1
# #Looking4ASpot 1
# diff 1
# Simpson 1
# hahaahahahaha 1
# uy 1
# PR 1
# cuddly 1
# @ShernScott 1
# golf 1
# Manila 1
# grepe 1
# Winchester 1
# http://t.co/rZ3BBeChHD 1
# bit 14
# never 50
# cool 5
# joy 1
# #giachietittiwedding 1
# #quote 4
# FOUR 1
# trains 1
# @taylorchurchman 1
# 07:34 1
# explosions 1
# @toninicho 1
# USA 1
# @Radio702 1
# Austin 1
# date 3
# #inspy 1
# @MyUS_Shopaholic 1
# meowkd 1
# CR 1
# whenever 1
# visa 1
# ok 24
# Xbox 1
# drag 3
# shave 1
# http://t.co/BLZEq3EqBe 1
# @GGStepit 1
# @attepate 2
# @taekookfever 1
# nisrina 1
# Inter 1
# anta 1
# #bestweekend 1
# Afsos 1
# ta 1
# Welsh 1
# three 5
# pack 3
# fifth 1
# #louisiana 1
# Bumped 1
# @DEPORSEMPRE1 1
# prolly 1
# @achiralk 1
# Jemma 1
# musicas 1
# @LanaParrilla 1
# tanned 1
# VIBRATING 1
# Thapelo 1
# hain 2
# Georgia 2
# Babyy 1
# Version 1
# Back 1
# ahhh 2
# BESTFRIEND 1
# stomping 1
# holiday 16
# HUHUHU 1
# @azzzzyb 2
# blight 1
# @larryequality 1
# Help 5
# DRI 1
# Goodluck 1
# @GBiebs17 1
# @jobhopjulie 1
# homed 2
# chose 1
# @Showmasters 1
# Dress 1
# merchs 2
# Sunny 1
# @Ami_Khang 1
# seekly 1
# NICE 1
# + 14
# separated 1
# Wet 1
# THOSE 1
# @JindalDaily 1
# bandana 3
# @Gonzo 1
# wan 1
# 468 1
# Stack 1
# action 2
# painting 2
# ordered 1
# @ValiantComics 1
# multiple 1
# snake 2
# & 102
# lottery 1
# sodas 1
# Popped 1
# #goodmusic 4
# http://t.co/Ty5Uar0Rmy 1
# going 83
# #LLAOLLAO 1
# #TGIF 1
# roof 2
# http://t.co/hoVZi9wQnx 1
# problem 6
# thru 2
# Then 4
# criminal 1
# https://t.co/KQ2pDd30w8 1
# device 1
# @realmadriden 1
# stalking 1
# @Sitarai 1
# things 21
# premium 1
# bookmark 1
# staff 3
# @TheOnion 1
# matter 3
# July 9
# must 14
# @lukesdagger 1
# translator 1
# 💫 1
# attempt 1
# http://t.co/RZTM0VKIlM 1
# minded 1
# Children 1
# yeahhh 2
# unstan 1
# Studio 1
# #igersoftheday 1
# doctored 1
# option 3
# Schools 2
# yunnie 1
# mee 1
# belated 1
# http://t.co/QdYWa03z1F 1
# interactive 1
# swapping 1
# Bakar 1
# tgk 1
# init 1
# studying 1
# size 8
# recordings 1
# otherwise 2
# code 8
# Boaz 1
# everyone 21
# tELL 1
# http://t.co/s5a7H7pd9x 1
# @21dadoongie 1
# #Sensiesha 1
# mana 2
# Honesty 1
# nalamannn 1
# @badoeuf 1
# televoting 1
# @DominionSyfy 1
# scoups 2
# http://t.co/jJboDo6LYZ 1
# narcos 1
# @guardianmusic 1
# LINE 2
# nnnoooo 1
# theme 2
# @CelestialZephyr 1
# @TheMercedesXXX 1
# visit 9
# Payment 2
# @JaDine_Addicts 1
# @FrantaAndBiebxr 1
# language 4
# http://t.co/CyZFCZFkjY 1
# Crepes 1
# prison 1
# #PKwalaSawaal 1
# days 48
# viewing 1
# common 4
# imy 2
# def 3
# IceCream 1
# ZAYYYYYN 1
# moved 4
# jaysus 1
# vouchers 1
# Next 1
# LOL 4
# @RocksteadyGames 1
# board 1
# @Swisscom_de 1
# Cream 1
# Darn 1
# @wigdogg 1
# exp 1
# @Joe_Sugg 1
# #AIRFIELDS 1
# LMAO 3
# mins 6
# Na 1
# grandma 1
# 144p 1
# jadi 1
# now 148
# Trust 1
# audience 1
# foot 2
# 🎀 1
# ol 1
# Leaving 1
# music 8
# https://t.co/cUCqzzhIbY 1
# @Loganchance 1
# AFTER 1
# Sel 1
# state 3
# can't 167
# http://t.co/MS60gaiIce 1
# asf 1
# @glennlondey 1
# turtle 1
# lover 1
# nawwwee 1
# challenge 1
# Starving 1
# carrot 1
# @Kryaotic117 1
# digital 6
# https://t.co/OiAHorQJOb 1
# agonising 1
# said 33
# dangit 1
# @twcxmina 1
# Unknown 1
# Rain 3
# @RobinhoodApp 1
# II 1
# Konga 1
# know 124
# financially 1
# tyas 1
# Kbye 1
# venice 1
# aing 1
# Gutted 3
# human 3
# sounds 5
# promote 2
# tipped 1
# #camsex 5
# disgusted 1
# @Ashton5SOS 1
# @haxllaark 1
# racial 2
# tank 1
# #kik 35
# @stylesandjord 1
# file 1
# van 1
# jelouse 1
# suspemsion 1
# ilhoon 1
# ave 1
# @Coles45Coles 1
# credit 2
# @cuffyochickenn 1
# clear 2
# senight 1
# @princesswhut 1
# texts 2
# @misses0wl 2
# dose 1
# socialising 1
# @Scruffbucket 1
# offer 5
# @OTRJSJ 1
# swear 6
# By 2
# #ChoiceInternationalArtist 5
# >:( 47
# range 2
# @Tinkering_Love 1
# Tommy 1
# BECAUSE 3
# 😘 11
# TV 3
# @tmhsposey 1
# @J_E_S_S_E__ 1
# #me 1
# hot 13
# 3a2ad 1
# @riseagainst 1
# @xsushie 1
# @eyeammarkk 1
# gig 1
# unsafe 1
# @alwafa 1
# SHOCK 1
# she'd 1
# cry 17
# https://t.co/XwpUutxD60 1
# @abigailjacinthe 1
# Hogan 3
# Four 1
# QIH 1
# WHHR 1
# Darlene 1
# @notch 1
# snakes 1
# Kylie's 1
# @tweetseamus 1
# pleaaase 1
# top 5
# 20/1 1
# @Techverse_in 2
# http://t.co/kgpUCPTdAx 1
# Meck 1
# @ManLikeSergio 1
# @rainymondays 1
# geez 1
# roommates 1
# fair 11
# http://t.co/y8RcKiqSZ3 1
# @fatinrafezall 1
# @nogitsunerd 1
# DOLLAR 1
# ONCE 1
# Sleepy 1
# http://t.co/jaASB4KjE1 1
# raha 1
# #sexting 1
# shoes 2
# OI 1
# fan 12
# aw 18
# EXERCISING 1
# entire 5
# write 8
# #LouisianaShooting 1
# BIS 2
# Nothing 3
# school 28
# sour 2
# Snapchat 10
# #kidschoiceawards2015 1
# spares 1
# @EdeLabayog 3
# @thebodycoach 1
# ciao 1
# setter 1
# Arch 1
# > 15
# SUAY 1
# wtf 11
# enough 22
# upsets 1
# @JackWhiteMedia 1
# @beamiller 1
# April 1
# car 9
# @b3gringo 1
# night 44
# @prophdog_ 1
# regional 1
# #PCUpgrade 1
# @karinatuano 1
# pets 1
# 3rd 3
# http://t.co/HDgBmwYSRr 1
# @IvyTenebrae 1
# BABY 3
# @INyan99 1
# gi 2
# @larssycutiee 1
# security 4
# @HoneyDogKimura 1
# ___ 2
# NOISE 1
# ed 5
# Inca 1
# Hsm 1
# shape 1
# #VIETNAM 1
# @SPObabbby 1
# collection 2
# TO 25
# GIRLS 1
# risky 1
# Camara 1
# fishing 1
# @_patnicolexx 1
# picture 11
# @triassy 1
# tweeting 3
# @lollypng 1
# instore 1
# TAY 1
# @celine_s16 1
# #amateur 5
# brings 1
# chum 1
# http://t.co/1nPlTqukIY 1
# 😏 4
# apink's 1
# hws 1
# muddy 1
# @andylimko 1
# caste 1
# nobody 4
# theo 1
# @lukelegs69 1
# don 5
# @DigiWorks78 1
# @CoreyHenson15 1
# @bammyxoxo 1
# https://t.co/OZdMHNQbSU 1
# @Hannahphern3lia 1
# chelsea 1
# https://t.co/DgynGEpHuH 1
# zenmate 1
# @itsAmarantha 1
# #twitter 2
# @DestinyNews_net 1
# WIN 4
# Las 1
# @chantalYM_ 1
# rt 6
# boring 5
# fugly 1
# creamist 1
# taking 6
# @miahyooow 1
# leftovers 2
# @EcoGitesLenault 1
# @therp_stefan 1
# @lauraho1992 1
# AND 65
# Sams 1
# onscreen 1
# @EllaHenderson 1
# target 1
# compensation 1
# tote 1
# Price 2
# Lol 5
# Lloyds 1
# #NBHeroes 1
# qt 1
# @GIJojo2 1
# @sarahlohse 1
# https://t.co/QtJBLWWLhy 1
# yea 2
# girl 17
# Abby 2
# account 15
# chipotle 1
# @sambirmingham2 1
# #AraGalang08 1
# Allah 3
# Hamstring 1
# @NintendoUK 1
# bang 1
# diagnosed 1
# #fuck 2
# Link 1
# #whereisthesun 1
# @NICKIMINAJ 2
# waking 7
# redirected 1
# @peacemakeruk 1
# AVAILABLE 1
# @blairforce2 1
# aytona 1
# 12th 1
# classy 1
# sweater 1
# gets 9
# @WingsScotland 1
# accept 1
# shades 1
# fancy 1
# HIM 3
# women 5
# rice 1
# Lovebox 1
# Panem 1
# odoo 1
# @apriloumay 1
# then 54
# thnkyouuuuuuuuu 1
# mam 1
# plaster 2
# alien 1
# @theohurts 1
# @shokako1104 1
# Fuq 1
# @sociopathslut 2
# Jess 1
# SFV 1
# lrT 1
# @HiddlesSupport 1
# http://t.co/teCUf9c9yc 1
# shakes 1
# @whoisaaronlau 1
# shared 1
# situation 2
# Victims 2
# APINK 1
# pampered 1
# @maknaekookie 1
# WANNA 5
# #failsatlife 1
# @milesfloresss 1
# Cleaned 1
# @zoullgab 1
# @narendramodi 1
# http://t.co/FDmw6B7jAL 1
# @MadridGamesWeek 1
# fursat 1
# @junghooked 1
# addition 1
# pora 1
# https://t.co/hIBjz4fC2r 1
# @paynepowerr 1
# @jehyop 1
# @highimvale 1
# kernels 1
# @pagodane 1
# ramd 1
# @Noin007 1
# mashup 1
# wednesday 2
# @fondprince 1
# gifs 1
# hahahaha 5
# Russian 1
# satisfied 1
# Erica 1
# CONFETTI 1
# AT 1
# nicest 1
# hay 4
# @dumplinghoya 2
# route 1
# Rumbelle 1
# wht 1
# notion 1
# Tirtagangga 1
# bank 7
# @benedicksawal 1
# Ross 1
# T 8
# minha 1
# dog 10
# third 1
# listen 10
# KNOW 4
# awsme 1
# #CNN 1
# @RuneMagique 1
# yup 4
# @ANTHONYFTSIVAN 1
# watching 17
# london 1
# @isalouise2012 1
# AE 1
# 1k 2
# sentir-se 1
# prescription 1
# flying 3
# @shakyra_cledera 1
# politics 1
# tears 1
# MEAL 1
# WTF 2
# Ive 3
# To 4
# desc 1
# agains 1
# walked 1
# barbells 1
# #BOMBING 1
# WORK 1
# June 3
# Hey 12
# 321 1
# @seungwannabe 1
# @itisfurny 1
# @tyrafendy 1
# teal 1
# @tallertara 1
# surely 2
# 25 3
# sight 1
# ging 1
# Weird 1
# fank 1
# #wakeupGOP 1
# Srsly 1
# SHE'D 1
# eggs 1
# gift 10
# claim 2
# tumblr 1
# dissapointed 1
# legends 1
# 》 210
# @soorjugn 1
# Full 1
# @ohmydayz 1
# @Meem_Hye 1
# @SANDEUL203092 1
# asap 1
# @MissKittyDomme 1
# @lucyreesxo 1
# bummed 1
# way 42
# pie 1
# Same 3
# @sasaribena 1
# poc 1
# medication 1
# #Frustration 1
# errors 2
# Stress 2
# vote 4
# aisyah 1
# TOMMYY 1
# Their 4
# @marmaisxcz 1
# game 18
# ugh 15
# disgusts 1
# Definitely 1
# https://t.co/JxjroN8PcY 1
# cartoon 1
# @AdoreDelano 1
# cycle 2
# @ShellyBarker123 1
# Hoping 2
# @OpTic_Mochila 1
# @Errata_0 1
# biggest 3
# entertain 2
# might 9
# Nope 2
# randomly 1
# fbc 3
# Louis 1
# Tobermory 1
# bean 1
# Hong 1
# @atiraxia 1
# @eydiespi 1
# f 1
# broh 1
# grow 2
# basket 1
# #39 1
# #video 3
# https://t.co/k7bFXN9H5V 1
# @sandwichlove_ 1
# @rcdlccom 1
# rosie 1
# recover 1
# @zazaraisovna 1
# O 4
# US 5
# 😪 3
# maverickgamer 4
# 14518344 1
# iceland 1
# owww 1
# sobrang 1
# during 9
# read 14
# thermos 1
# ( 1180
# ganas 1
# Imperative 1
# Hibbs 1
# @NikiNoox 1
# @1DMspree 1
# small 9
# pd 1
# banaya 1
# industry 1
# @karir_komal 1
# @jvkho9997 1
# antagonistic 1
# treats 3
# Taxi 1
# perspective 1
# stage 12
# pleaseee 1
# period 2
# @MegBowes_ 1
# earlobes 1
# @camilacabello97 1
# sad 111
# xxxxx 1
# One 3
# Is 12
# FAKMAREY 1
# @divine_zarryy 1
# computer 5
# did 57
# https://t.co/h7JKvKGOa5 1
# malaysia 1
# sem 2
# HUG 1
# balling 1
# double 3
# @Zoe91x 1
# #Brum 1
# dovey 1
# springs 1
# whaaat 2
# sucked 1
# @pookiportia 1
# feedback 4
# couldnt 2
# ny 1
# Toronto 1
# bebeee 1
# @plasticniki 1
# Sydney 1
# wna 1
# middle 6
# nosebleed 1
# Corey 1
# @smilingkrys 1
# I 1587
# http://t.co/THMLVQlDAw 1
# @cathjenkin 1
# pick 7
# reunite 1
# corrupted 2
# wrong 31
# https://t.co/jliVpKmFwG 1
# incident 1
# being 46
# removed 3
# band 2
# tom 2
# upgrade 1
# @waxxa_official 1
# time 136
# snippets 1
# @vijaysrivatsan 1
# #MOTN 1
# un 1
# 1/2 3
# Jhezz 1
# Play 2
# @haywayne 1
# ano 2
# ifeelyou 1
# yourself 6
# Splendour 1
# werk 1
# He 8
# @aurorakween 2
# that 263
# https://t.co/S8cq6c91ni 1
# sweetest 1
# @rosieofthejones 1
# forward 6
# didnot 1
# reach 1
# babysit 1
# ` 3
# LOT 4
# Britain 1
# sweetie 2
# character 1
# lose 4
# what 99
# immovable 1
# junmyeon 1
# http://t.co/PQyN3HNJ33 1
# @cherryboyJJ 1
# #ThatsCold 1
# box 7
# pcb 1
# members 5
# loses 1
# girlfriend 2
# #bbloggers 1
# TIMES 2
# hahahaokay 1
# ankle 3
# R 4
# jordans 1
# awwwwwwwwwww 1
# QUALITY 1
# mom 10
# Meydan 1
# � 21
# @TheActualKing 1
# @MyNBA2KRT 1
# tryna 2
# chance 13
# @RafaelAllmark 8
# @TritanArmyv2 1
# programmes 1
# @sir_mancio 1
# @feleciaag20 1
# SAME 6
# @sabfkhan 1
# Steven 2
# NSTP 1
# 130 1
# field 1
# 805 1
# @covtelegraph 1
# @RMBLees 1
# raining 12
# kate 1
# quote 1
# http://t.co/BtE6DMoxYT 1
# https://t.co/6o3ZgNOnvh 1
# @CandySalvatore 1
# whatchya 1
# keedz 1
# apologize 1
# https://t.co/7HTgd85HfF 1
# Jackson 2
# 121st 1
# @FilthyFrank 1
# @gotshinee 2
# ive 7
# allowance 1
# @94tmhhes 1
# Music 7
# penis 1
# @yeymp3 1
# foundation 1
# angel 2
# deeply 1
# helpppp 1
# stared 1
# @RedLipsteeq 1
# #sexo 2
# gurl 1
# hugs 12
# tolerates 1
# trade 2
# #couple 1
# @FreshDecorators 1
# SINCE 1
# @hawkins_g 1
# @R_steeez12 1
# @The_Strypes 1
# @dialoglk 1
# @kidrauhLogan 1
# petite 1
# AGAIN 3
# https://t.co/sIvKwcomiZ 1
# mayor 1
# @Lizarrdz 1
# intermittent 1
# @kristikay13 1
# kian 2
# @crreatura 1
# Awww 4
# #Fenestoscope 1
# booking 1
# HERE 2
# driving 7
# #girl 1
# below 1
# ICE 1
# NIWLL 1
# @ayyedolans 2
# @TheSvante 1
# pano 1
# gf 3
# http://t.co/BWNMCNBvnC 1
# new 43
# better 35
# matters 1
# @LightAgayi 1
# PAS 1
# @SpoilerTV_BATB 1
# @_Millzxy3D 1
# collat 2
# @BacheloretteABC 1
# spinning 1
# #shithouse 1
# http://t.co/1J3qYUTTqG 1
# __ 2
# PICK 1
# #Bellevue 1
# Hmm 1
# appreciated 1
# test 5
# https://t.co/xSRggfOijW 1
# fool 1
# performance 2
# http://t.co/oI0pYGUsDi 1
# 423 1
# @DaveGorman 1
# http://t.co/CfOxw5wljZ 1
# NHS 2
# ikr 2
# tinder 1
# Too 9
# A 28
# FULL 1
# business 2
# @NinaBejar 1
# @GodfreyElfwick 1
# deserves 1
# coyote 1
# * 67
# Ihhh 1
# @iphonetips1 3
# fk 1
# @alisakmr 1
# #musicbiz 1
# @SaikyoRyouT 1
# @shwetadaga23 1
# Distant 1
# California's 1
# pesos 1
# #wet 6
# @nextofficial 1
# Poor 10
# Call 2
# Reynold 1
# sensor 1
# @Herreraholic 1
# @KumonePina_bot 1
# thank 22
# sia 1
# hotaisndonwyvauwjoqhsjsnaihsuswtf 1
# 348 1
# goods 1
# #Tcot 9
# nooooooo 1
# tweets 8
# @WillHillBet 1
# @DrishyamTheFilm 1
# @JabongIndia 1
# ocean 1
# congrats 2
# mads 1
# ANS 1
# current 1
# http://t.co/u6M5qQTXxv 1
# convinced 1
# idol 2
# SNOW 1
# @GAYPERlON 1
# @Pahimar 1
# @louisacasson 1
# prepared 3
# Hulkamania 1
# @_GrahamPatrick 1
# @SVTNDino 1
# #kikmenow 9
# PUPPY 1
# Youtube 1
# fault 3
# x's 1
# era 1
# belly 1
# @ughponcong 1
# @VGO__ 1
# @ITVCentral 1
# @jenalive11 1
# Ayemso 1
# 45 1
# #xxx 1
# 23rd 1
# quickly 2
# 2hrs 1
# dia 2
# @PiooooPiolo 1
# @OandtheFoxes 1
# geng 1
# @Beyfan1981 1
# Megan 1
# anna 3
# session 4
# @LeagueOfKnockup 1
# decides 4
# @wwedrzziy 1
# @GaganCh57575757 1
# giveaway 2
# pausing 1
# restricted 1
# hear 31
# water 6
# kisses 2
# face 18
# 00128835 1
# Are 7
# Premiums 1
# brk 1
# ofc 1
# @cabeIlovato 1
# messing 1
# oMG 1
# Macho 1
# pissbaby 1
# wae 1
# starbucks 2
# row 3
# :( 4585
# @londonbakes 1
# @Vanessauhhh 1
# @MariajoseCleri1 1
# ally 1
# PM 4
# arresting 1
# series 3
# product 2
# buddies 1
# @RunJumpScrap 1
# @zappygolucky 1
# tuesday 1
# idek 1
# TammiRossM 4
# omaigoshhhhhhh 1
# redeem 1
# #Louisiana 1
# 190s 1
# @Vitality_Watson 1
# parts 1
# 59 1
# fucks 1
# Ouch 3
# @basara_capcom 1
# @Jam_sponge 1
# tempted 2
# Robyn 1
# #RIPSandraBland 1
# more 79
# rlyyyy 1
# DZ9055 1
# bills 4
# yah 3
# Arianator 1
# lot 20
# @thepohjien 1
# @corey_buckner 1
# extensions 1
# 4.4+ 1
# @bae_ts 1
# @iain225 1
# until 22
# pm 4
# Know 1
# Sissi 1
# feels 11
# https://t.co/QfTrANs4Yd 1
# sign 6
# CHSWIYFXCSKCALUM 1
# pink 1
# http://t.co/Vr3ICTaFIS 1
# @gracioussam 1
# Confidence 1
# forgetting 1
# @tanha_messiah 3
# survived 1
# Wat 1
# notifications 2
# 190 1
# 33 1
# nahi 1
# @AndreaMarySmith 1
# scale 1
# smith 1
# @lynshields 1
# @iperfectyonce 1
# attacks 2
# Fred 1
# @laylaharden 1
# where 42
# heavy 2
# saaaaaaad 1
# Bristol 1
# @Wilpy1 1
# soccer 2
# backstory 1
# precious 4
# @DollyyDaydreams 1
# effin 1
# emotionally 1
# @iMac_too 1
# 21st 2
# @ZahraMubeen 1
# @__Zanele 1
# nooooope 1
# ANOT 1
# depressing 4
# back 115
# maging 1
# @evanquick 1
# inflation 1
# @makerofhats 1
# @imNadies 1
# @yslzaint 1
# @sophiasam013 2
# @Slay__N 1
# JannieCam 1
# mujy 1
# thenting 1
# tweeted 4
# ] 6
# expectations 1
# send 9
# @AhmedMarzooq 1
# weekly 2
# lectures 1
# @chrisisk 1
# http://t.co/On2ijrtaxY 1
# #sexygirlbypreciouslemmy 3
# doing 23
# vist 1
# @iamcharleigh_ 1
# Bang 1
# 9pm 1
# Far 2
# takes 2
# @nichotine_ 1
# fans 5
# #Unknown 1
# Aur 1
# m's 1
# begging 1
# ;-) 1
# intolerant 2
# hai 10
# #premiostumundo 2
# buckling 1
# taxed 1
# Olivia 2
# Potager 1
# http://t.co/dNSaPwiUQA 1
# herself 2
# @thnksfrdllnwks 1
# site 6
# @ThermoGrenade 1
# grandmother 1
# Cayton 1
# http://t.co/GpY6E9jHUI 1
# MAKE 1
# IVE 1
# @KPAKeele 1
# KEENO 1
# http://t.co/I7N9cinihz 1
# @AnnieAppelle 1
# TECHNIQUES 1
# #Horny 1
# window 4
# kitty 1
# slr 1
# Lion 1
# bucket 1
# @feltonbiebs 1
# only 67
# Hateeeee 1
# push 2
# @HeyImBeeYT 1
# @CancerReliefUK 1
# miserable 2
# couldve 1
# #Muslims 1
# @onikallah 1
# @Gatlinho 1
# enjoy 4
# @muhammadskates 1
# shocking 1
# http://t.co/5OLTvTAO95 1
# Fam 2
# Gayle 2
# @Froufrou42 1
# ALL 1
# still 104
# http://t.co/Ksdgy0lTpF 1
# #model 3
# Sony 1
# @emre_lavigne 1
# FUCKS 1
# determined 1
# Abrupt 1
# @Asiasoft_Live 1
# oldies 1
# billions 1
# THERES 1
# tests 1
# @alma 1
# Ahhh 1
# cafe 1
# @brewdog 1
# fela 1
# entries 2
# → 1
# Mum 1
# spike 1
# of 352
# DAY 1
# iam 1
# @HaticeBieberr 1
# privilege 2
# sbali 1
# outfit 5
# bridesmaid 1
# Hasya 1
# @MissRoosj 1
# @CHEDA_KHAN 1
# @RoySayWhatNow 1
# 0.001 1
# class 6
# @loststhewar 1
# knives 1
# inputs 1
# @DaShawnBullfrog 1
# @SBS_MTV 4
# cookies 1
# #skype 4
# @AmadoraGourmIce 1
# @JeffyPie 1
# @angelicaorganic 1
# @SimoontjeVera 1
# #TheAccidentalCouple 1
# fun 32
# semester 2
# debut 3
# plant 2
# @BelleSGlasgow 1
# UNFOLLOWER 1
# soooo 1
# BRIDE 1
# welder 1
# AF 2
# Dogs 1
# sometime 2
# @ScarletBlue9 1
# On 3
# #m5m6junction 1
# https://t.co/T0VTMpqams 1
# @schnuckster 1
# kandekjs 1
# @GeenaEhlich 1
# Crumble 1
# pride 1
# 🎂 2
# MS 1
# AAAHHH 1
# jokes 2
# Now 11
# Chloe 2
# @countrychoiceID 1
# guests 2
# nila 1
# #blonde 2
# @mikecom17 1
# @ThisIsTheBrooks 1
# https://t.co/EzfeHMTT5S 1
# sun 8
# IT 18
# 🌃 1
# survive 3
# exception 1
# doable 1
# http://t.co/ziJiJYLDXT 1
# @Whorgeee 1
# super 10
# https://t.co/cX9MmWnRA4 1
# playin 1
# eve 1
# @BAP_Bangyongguk 1
# hp 2
# تكفى 1
# @gala_con 1
# google 1
# bald 1
# suma 1
# FAIR 1
# FREAK 1
# #Cyprus 1
# YOU 58
# Shepherds 1
# #taeny 1
# thessidew 1
# hi 12
# yourselves 1
# YOUUUUUU 1
# space 5
# sux 1
# https://t.co/9fcwGvaki0 1
# @baexrv 1
# @GP2_Official 1
# @GutterdogUK 1
# major 2
# login 1
# @dtaylor5633 1
# @kevrobbo27 1
# @AlexandraBjelk 1
# tried 11
# Shawn 1
# ENG 2
# In-sensitiveness 1
# seehiah 1
# police 3
# Around 1
# F 3
# #soulsurvivor15 1
# thrown 2
# niNASTY 1
# @NicoIrishNews 1
# Collaboration 1
# sure 29
# linis 1
# http://t.co/zzwd8HDcOI 1
# 💞 4
# bleak 1
# wish 79
# @CorCor84 1
# brave 1
# gulo 1
# non-trial 1
# Actually 1
# Gonna 2
# https://t.co/Hv1i0xcrL2 1
# mwa 1
# Visual 1
# dress 5
# awuna 1
# ｡ 8
# @krysseners 1
# @mamdouh733 1
# ready 10
# Less 1
# @lvl26highelf 1
# 💕 7
# mind 6
# EYES 1
# Yep 2
# r 15
# before 37
# legend 2
# concepts 1
# Dream 2
# shorter 1
# maps 1
# Ma 1
# momma 1
# K 2
# breathe 1
# speck 1
# https://t.co/k1MWoiqBiy 1
# darcey 1
# @Randeep_HoodaFC 1
# There 6
# #txt_shot 1
# @archietalanay 1
# shits 2
# munchkin 1
# altered 1
# inital 1
# Muller 1
# broke 8
# Huhu 2
# Nirame 1
# I'M 5
# @NZRR_S3 1
# kid 8
# @MatttCastro 1
# thanking 1
# Show 1
# apart 5
# Christ 1
# ALLAH 1
# @DanReeve86 1
# grey 1
# WEEKS 1
# @AnjariaSameer 1
# grande 1
# 5SOS 5
# 4-5 2
# suck 4
# vet 1
# cross 2
# KLM 1
# journo 1
# zokay 1
# If 13
# mwah 1
# velvet 1
# diesel 1
# 2nd 5
# chopped 1
# caaaannntttt 1
# #Elgin 1
# Tbh 2
# @TinyKyrus 1
# Kath'd 1
# @Morrisons 2
# Where 6
# PROBS 1
# Aug 1
# infront 2
# rtd 1
# IJ 1
# staying 2
# Bale 1
# think 62
# Woza 1
# AGO 1
# #kikchat 9
# plug.dj 1
# ming 1
# @byunboobs 1
# @mrBobbyBones 1
# @howarth_83 1
# lcs 1
# sorted 1
# pramis 1
# degrassi 1
# feelings 7
# gahhh 1
# stopped 6
# @crownhyoding 1
# jimin's 1
# @xaimrose 1
# gfriend 2
# flipping 2
# sandwhich 1
# finally 16
# Witnessed 1
# structured 1
# rn 16
# fries 2
# @MalcolmInx 1
# Insurance 2
# @TPOuk 1
# mbulelo 1
# verry 1
# chalet 1
# MovNat 1
# UNICEF's 1
# @peachymin 1
# similar 4
# @keelzy81 2
# M4 1
# Swimmer's 1
# #romance 1
# brendon 1
# @sarahbournex 1
# Ps 1
# FOLLOWK 1
# @TotallyWonwooed 2
# chocolate 7
# @NeoGrove 1
# didnt 21
# uniting 1
# Buset 1
# 17th 1
# cursed 1
# font 2
# Gorgeous 1
# vv 1
# Yodel 1
# example 1
# @lilaclarents 1
# walnut 1
# ice 31
# Nathan 1
# @blockedmefat 1
# @aldenrichards02 1
# #ZaynIsComingBackOnJuly26 23
# SICK 2
# @larriii7 1
# @drcox63 1
# wkwkw 1
# SORRY 4
# WORE 1
# http://t.co/cvy1vBmqan 1
# instrument 1
# @PeterAspsjo 1
# Inside 1
# pea 1
# pak 3
# https://t.co/daFvzOR5qt 1
# @KollyBuzz 1
# @MonochromeEm 1
# imsorry 1
# haix 2
# http://t.co/fwDwYoVEPV 1
# hamsters 2
# compared 2
# #RandomReboot 1
# upsetting 1
# girls 8
# laughter 1
# e-petitions 1
# varge 1
# #BlameShoghicp 1
# spam 4
# steam 2
# @teobesta 1
# sea 1
# That 14
# promising 1
# @Stormzy1 1
# Bungie 1
# charles 1
# VIDEO 1
# notice 22
# skin 1
# @mukesvlut 1
# kateee 1
# Theatres 1
# askies 2
# updates 2
# http://t.co/2lxZeZAhzE 1
# claws 1
# @realyys_ 1
# deactivate 3
# 24 11
# They're 4
# irking 1
# http://t.co/utDMqr0aAV 1
# excuses 1
# Raven 1
# @waniiamira 1
# @Markisskill 1
# switch 3
# @bbygjrlmgc 1
# Ha 2
# @_abbeytaylor 1
# DONATE 1
# karlia 1
# Nice 2
# turn 6
# zumba 1
# stupid 6
# must.be 1
# plus 2
# @parisianskies 1
# jace 1
# o 6
# colleague 1
# momo 1
# Guys 1
# @Camy19994 1
# Instead 1
# davao 1
# bf 1
# BEAST 1
# mine 10
# url 1
# Amber 4
# chemical 1
# summer 13
# @ellierowexo 3
# dicks 1
# @Mahmoud_Rida21 1
# Rome 1
# perfume 1
# hsould 1
# YEOL 1
# @djdayz 1
# Wifi 1
# replying 1
# attack 2
# 7782 1
# i'VE 1
# inapropriate 1
# IHOP 1
# pornography 1
# warmest 1
# https://t.co/1CThOoG9a1 1
# plsssssss 1
# shiatsu 1
# Bilbao 1
# Taissa 1
# vicky 1
# choma 1
# sudden 4
# saw 17
# Collecting 1
# glares 1
# BACK 5
# ＠ 5
# helping 5
# decided 3
# #atk 2
# Senpai 1
# @yearsandyears 4
# Nobody 5
# 2hours 1
# @bahadirylmz 1
# http://t.co/9U5yeDfqqg 1
# bites 3
# @biobio1993 5
# condition 1
# #indiemusic 10
# mosquito 1
# stepped 1
# urghhh 1
# evet 1
# minecon 1
# incompleta 1
# narrow 1
# @RichelleMead 1
# red 3
# gomen 1
# ME 165
# awful 12
# INSIDE 1
# Rodic's 1
# courage 1
# political 1
# smooth 1
# @ 17
# te 1
# @harIeyyquinn 1
# swiping 1
# psycho 1
# BETTER 1
# asian 2
# https://t.co/2Qg4dhxaGg 1
# Derby 1
# @GEMChannel 1
# http://t.co/gRQZ1LKTJF 1
# CAME 1
# unblock 1
# Vidcon 2
# WHATSAPP 1
# @PatelPatelxx 1
# copies 1
# @JessicaRyanFord 1
# HE 39
# installed 2
# lamon 1
# pc 1
# Suppose 1
# earth 1
# Ik 1
# hyung 1
# @perfect_st0rms 1
# BIG 1
# nat 1
# cement 1
# @__riixc 1
# lucozade 1
# bv 1
# tmw 1
# #horny 1
# manly 1
# @_ferdelicious 1
# internship 1
# horse 1
# cutest 1
# explain 3
# Wii 1
# IvyPowel 1
# cart 1
# Notch 1
# everything 13
# @hallarkd 1
# Bade 1
# Species 1
# #french 2
# Popol 1
# bcoz 1
# bison 1
# Capcom 1
# barking 1
# Bad 7
# #oralsex 4
# Crying 1
# @elyusia 1
# nje 1
# Sophie 4
# Kate 1
# @blackannesee 1
# #likeforfollow 3
# Luke 2
# babes 3
# @courtneypink07 1
# @J4PE5 1
# Harriet 1
# footy 3
# joke 1
# dare 2
# community 1
# Fever 1
# Roberts 1
# boys 9
# wHERE 1
# wounded 1
# @calvinrosorio 1
# @queenvause 1
# @YogscastLewis 1
# #Sadlyf 1
# @THESCORCHCRANKS 1
# @crazynovely 2
# BEEN 6
# chal 1
# #Israel 1
# SNAPCHAT 19
# @kalourd 1
# buuuut 1
# @isakigoboom 1
# count 3
# knowwww 1
# password 1
# death 3
# Inuyasha 1
# @harriep 1
# @dongvvoo1122 3
# told 11
# pits 1
# @cartinelliaf 1
# viewer 1
# gv 1
# swallowing 1
# @wearefreeradio 1
# thus 1
# lie 4
# 334 1
# @JoshMight69Her 1
# Shell 1
# Anyone 1
# limited 2
# erm 1
# Dull 1
# @___mew2 1
# moving 4
# context 1
# @mari_suunn 1
# @geekisnewchic 1
# @Charlottegshore 2
# ange 1
# #SayHerName 1
# LMFAOO 1
# condemned 1
# Lord 1
# Amelia 1
# untruth 1
# 350 4
# @dicehateme 1
# tooo 1
# checked 8
# @elegantxharry 1
# http://t.co/PDxVjLdhi7 1
# https://t.co/fAaZxMaG3u 1
# Change 1
# stiles 1
# https://t.co/JK8xRlW6IF 1
# whats 6
# @_RobLong 1
# @latersbby 1
# EDSA 1
# essentially 1
# Food 2
# 915 1
# @GuadaSSanchez 1
# 💪 2
# #addme 1
# Can't 13
# titas 1
# @likeafigure8 1
# home 56
# realised 1
# bio 3
# dom 1
# Xur 2
# cards 2
# muster 1
# mrs 1
# {: 1
# countdown 1
# horrific 2
# 13th 1
# @jsjvngrf 1
# Exclusive 1
# muka 1
# @MiaCousins 1
# NOTICED 1
# rumor 2
# frog 1
# @cooldigangana 1
# Xxx 1
# share 6
# @akawhatadave 1
# NOTICE 1
# wondered 1
# Shootings 1
# https://t.co/Jr4U98A8ja 1
# Deth 2
# feet 3
# @irisharry_ 1
# ω 1
# prefer 2
# @JDRaPlD 1
# @hyungwons_ 1
# sees 1
# Glad 1
# @reeceftcharliie 1
# @AmandaT_Photo 1
# sp 1
# @CameronNeil 1
# stressed 2
# panels 1
# @Belinda_Factor 1
# jack 1
# gone 21
# Hes 1
# proud 6
# anon 2
# tard 1
# eh 2
# Pubs 1
# @NotRedbutBlue 1
# poppin 1
# sucks 15
# Tagal 1
# interaction 1
# mode 2
# https://t.co/5WyrdvjzSf 1
# @LBHCRM 1
# SO 68
# @iTunes 1
# @Silverio_Lanzzz 1
# http://t.co/V8OH886Z2Z 1
# DOSENT 1
# killing 10
# toy 1
# MAT 1
# 3 37
# chrompet 1
# @MillerKaapke 1
# devices 2
# @durnurr 1
# whay 1
# Pakighinabi 1
# 3am 2
# FORGETTING 1
# Club 1
# fucking 15
# http://t.co/75IDDesHD0 1
# @interpedia_ 1
# smoking 1
# foreals 1
# @pastelwolfxx 1
# @2baconil 1
# @wbuharryy 1
# pumpkin 1
# @farhani_nfr 1
# @SwitInno 1
# https://t.co/IpxqMQWFeM 1
# W 1
# climbing 1
# @KimDyvotees 1
# certainly 2
# zz 1
# apartment 1
# NODE 1
# done 24
# midnight 2
# @izzsugden 1
# 18th 2
# Polaroid 1
# child 2
# cheeky 1
# @CarltonFC 1
# classes 2
# http://t.co/iVcyNmm8vP 1
# veeeeerry 1
# @itmeailung 1
# Depends 1
# secondary 1
# tries 1
# jot 1
# tay 1
# sandwich 3
# Sunway 1
# meeee 1
# tdy 1
# fire 1
# @MissStaceyVee 1
# CNN 1
# pension 1
# bees 1
# @swiftstruelove 1
# blog 1
# gorilla 1
# http://t.co/qtgCn7Wi1P 1
# busier 1
# Worlds 1
# @iamnonexistent 1
# @sweetbabecake 1
# 😞 3
# hernia 3
# @carliot23 1
# seems 7
# Et 1
# live 26
# crafting 1
# Ken 1
# #FreebieFriday 1
# Wrong 1
# @infinite7muse 1
# Everything 3
# @bowserrh 1
# Damn 2
# True 3
# 5am 5
# logged 1
# nightmare 4
# persona 1
# ticket 4
# @Wufanited 1
# package 1
# normal 3
# greymind 2
# Delph 4
# Jeebus 1
# perfect 1
# Dheena 1
# @pinkle_dhesi 1
# til 5
# @LeanneHirst 1
# AFTERNOON 1
# @GazetteBoro 1
# hella 4
# Image 1
# hope 52
# games 9
# @TheCumiaShow 1
# ख 1
# @KristineMayor 1
# pish 1
# knew 5
# Nelle 1
# GUYS 11
# riding 1
# @__Crow__ 1
# RHD 1
# @ForbiddenPlanet 1
# bore 1
# dad 8
# shipping 3
# beato 1
# In 4
# forecast 2
# Heart-breaking 1
# opt-outed 1
# Raspberry 1
# pierced 1
# unhealthy 1
# under 3
# braces 2
# @ColtZoom_ 1
# harap 1
# through 13
# blast 1
# expired 1
# @ManmarzianFC 1
# construction 3
# papertown 1
# @maui26_maui 1
# monkey 1
# planner 1
# Sheff 1
# pro 2
# @TrevvyM114 1
# @missmbuga 1
# 30th 1
# @TitusOReily 1
# Podiatrists 1
# ups 2
# http://t.co/84sCIHx8A4 1
# https://t.co/8To7Kej1ZP 1
# http://t.co/rInVNwnDyZ 1
# age 2
# http://t.co/6G6C7ewfpf 1
# lil 7
# @ranaPTX_ 1
# @crushinghes 1
# @junior_jones 1
# yesterday's 1
# wrocilam 1
# bt 2
# @martylog 1
# @FuzionDroid 2
# HAVENT 2
# starting 3
# About 1
# ho 3
# supposed 6
# buttttttt 1
# @JerryFitzgibbon 1
# livestream 1
# lolo 1
# ENDED 1
# YEAH 2
# Vidic 1
# ha 5
# free 16
# sweetbj 1
# http://t.co/fVV9Y3WX2o 1
# vehicles 4
# @mcbride_alex 1
# choice 5
# @yg_melissa 1
# smart 1
# milk 3
# lets 2
# @f0ggstar 1
# wali 1
# uSanele 2
# laomma 2
# afropunk 1
# @comedyorjoke 1
# top-up 1
# @OhHeyItsAJ 3
# torture 1
# planted 1
# dat 3
# dumbest 1
# postcode 1
# beta 4
# thats 9
# promised 1
# @Benzyyyyy 1
# https://t.co/IObpbythB8 1
# Icarus 1
# @endohope 1
# @byStegi 1
# @alexxmitchy 1
# misses 3
# eyebrows 1
# soshi 1
# hozier 1
# FAMOUS 1
# @_avonsparadise_ 1
# #ExpediaJobs 1
# KE 1
# patwari 1
# Scotland 2
# Armor 1
# spree 3
# @TheGautamGulati 1
# @cxshtonhemiford 1
# swollen 1
# SMS 3
# evening 2
# #Haaretz 1
# @fivedorkz 2
# @dpcrazen1001 1
# warning 1
# mush 1
# dunno 1
# world 16
# Vivian 1
# quotes 1
# @AnaMyID 1
# TT.TT 1
# http://t.co/iF9jbN3cgm 1
# trespassers 1
# plot 1
# #hannibal 3
# Sone 1
# s 23
# Alice 3
# @tudipa 1
# lu 1
# @Therp_BV 1
# Carva 1
# ZIAM 1
# shitty 1
# Product 1
# @TasteofLondon 1
# TRIPLE 1
# male 1
# Pengen 1
# @ciaellB 1
# sorrrrryyyyy 1
# े 1
# soln 1
# christine 1
# co-worker 1
# @LivingLifeNottm 1
# BESST 1
# pretending 1
# @HolyHardwell 1
# @bdunkelman 1
# Millz 1
# appeared 1
# Pffff 1
# Final 3
# 338 1
# Vegas 2
# http://t.co/xNe3cD6dvk 1
# bought 6
# floating 1
# self-XSS 1
# killer 1
# afford 7
# 6g 1
# cupcake 1
# wings 2
# any 54
# drowned 1
# Benzema 2
# @Wkshaffer 1
# cow 1
# aready 1
# @marmice08 1
# @Taylorr0se 1
# ppl 5
# worry 4
# @bandq_help 1
# boo 2
# certain 6
# @Airtel_Presence 1
# EGG 1
# @grace_phipps 1
# #GetWellSoonAmber 1
# Friday 9
# eps 2
# wake 11
# #selfie 2
# anxiety 3
# @biancahequibal 1
# AirDroid 1
# @tv3midday 1
# @vanillawley 1
# needed 2
# http://t.co/CVOT0DGrAy 1
# rubbish 1
# Nigga 1
# @jrmychan 1
# @ShutUpPenguin 1
# YUKI 1
# COD 2
# cash 2
# ashamed 3
# @fittorot 1
# Dang 2
# Being 3
# wolrd 1
# #soon 1
# #QuitKarwaoYaaro 1
# Sympathis 1
# VidCon 1
# @Hayleychinney 1
# @yezzer 1
# @Tikus09 1
# #sabadodeganarseguidores 2
# LOSE 1
# tmr 2
# working 30
# lest 1
# Chilton 1
# https://t.co/ChzrqtelPh 1
# Mendes 1
# hen 1
# footage 1
# Naa 1
# Plains 1
# @helsy_1983 1
# Moving 1
# Anarchy 1
# @LuciHolland 2
# since 31
# thx 1
# @annisabolo 1
# growling 1
# dash 1
# #EidWithGrofers 1
# JOKE 1
# @KnucklePuckIL 1
# carriageway 1
# hrryok 2
# threatened 1
# sneaks 1
# sandwiches 1
# Ruth 1
# strokes 1
# lease 1
# Marino 1
# Banana 1
# @Mark23Baracael 2
# @LukeBryanOnline 1
# @annnalucz 1
# little 20
# #USA 1
# fat 3
# @diplo 1
# huge 3
# trend 4
# 11:11 4
# fnaf 1
# exam 3
# pepper 1
# @outsidezoella 1
# @ICTheatre 1
# #ThatSelfieThough 1
# Android 2
# AH 1
# hangin 1
# led 1
# #phonesex 2
# comfortable 1
# CREI 1
# DH 2
# wobbly 1
# MONDAY 1
# repacks 1
# @GlynHopkinShop 1
# wet 3
# hung 1
# cumbia 1
# Player 1
# we've 1
# Any 3
# shiiit 1
# MUCH 41
# Dying 2
# @WordOfTheFree 1
# @MoKurd 1
# SJ 3
# hoe 1
# fragments 1
# wit 1
# laper 1
# @FusazoJT 1
# @godstalia 1
# 2-5 1
# atty 1
# occasionally 1
# present 3
# HK 1
# IC 1
# 10 8
# OH 4
# DESERVE 1
# ramos 1
# #porn 2
# @wotjustin 1
# @shellbryson 1
# https://t.co/3NaRSAzIL1 1
# Finland 2
# Bebeeeee 1
# jacob 1
# relationships 1
# faraway 1
# As 6
# https://t.co/LGCx3ifqC7 1
# is 456
# shravan 1
# @katyperry 1
# @ajleestan 1
# this 270
# @tiaramescudi 1
# Euuuwwww 2
# @yuniizu 1
# LIKES 1
# jeslyn 1
# @DrBabarAwan 1
# That's 9
# emta 1
# beb 2
# bitching 1
# flops 1
# @curexcomplex 1
# @nicky_nick1998 1
# @ShannonEastwood 1
# blue 3
# #RandomRestart 1
# @littlejules14 1
# https://t.co/7M7pZMPw7u 1
# dots 2
# @theresaninkspot 1
# @haelic 1
# lego 1
# available 9
# Oppa 1
# WAS 2
# cornetto 2
# HIS 2
# 😊 9
# legible 2
# Service 1
# We 44
# drops 1
# 120 1
# threatening 1
# speed 2
# engineer 1
# kidding 3
# srry 1
# definite 1
# #PSYGustoKita 2
# aus 1
# niende 1
# @Akon 1
# hairy 1
# @JKCorden 1
# dev 2
# http://t.co/Br36TjVYNd 1
# tirade 1
# enjoyed 1
# doesn 1
# http://t.co/VM4N0n8Bkw 1
# @BeforeYouExit 1
# @thejcenaligway 1
# Brooklyn 1
# PS3 1
# @grindmegrande 1
# between 5
# broker 1
# say 34
# donghyuk 1
# @oH_So_EhmTee 1
# up 160
# chills 1
# @Salweimar 1
# #MMSMalubhangSakit 1
# @sahirlodhi 1
# YOLO 1
# gawd 1
# becoming 1
# #hotscratch 1
# https://t.co/HCMO09MhQt… 1
# enroll 1
# Sleeping 1
# Trafficccccccc 1
# Offered 1
# family 6
# anything 19
# oscar 1
# coughing 1
# http://t.co/zR2iuOYO5H 1
# 8p 1
# winning 2
# saaad 1
# were 40
# #socialrewards 1
# PARTY 1
# campaign 2
# @bbgurrll 2
# ADORABLE 1
# Ekk 1
# soo 3
# #MSNBC 1
# cologne 1
# Blog 1
# @SweetieBiebs 1
# salabraty 1
# Maggie 1
# kat 2
# @Calum36Chambers 1
# Ylona 1
# FOLLOW 77
# TALK 1
# NIALL 4
# sararocs 1
# boner 1
# hahahahaha 1
# #hotmusicdelocos 2
# #인피니트 2
# @MlREU 1
# Hahah 1
# wasnt 1
# shot 4
# @ShipsterUSA 1
# SUNGGYU 1
# hits 2
# madatte 1
# Financial 1
# https://t.co/TD8A5vEc9p 1
# best 19
# laugh 2
# @GabyWhittlenew 1
# eat 17
# @IVSofia 1
# @gclliva 1
# @MadniTahir 1
# 😍 1
# presents 1
# WOULD 1
# bring 8
# https://t.co/HcqK1IZBRp 1
# @5sos_solo 1
# http://t.co/S8cATQRzew 1
# MOM 1
# far 15
# ghantay 1
# tla 1
# modified 1
# UNTIL 1
# pay 5
# departure 1
# bun 1
# bday 6
# crapple 1
# yung 2
# #Guncontrol 1
# iPod 1
# run 6
# omaygad 1
# satire 1
# :) 2
# ilysm 3
# ngee 1
# kebab 1
# Cali 1
# amazing 15
# @gbrllx 1
# connection 2
# http://t.co/ldbydFruxA 1
# Sun 1
# bout 2
# poooo 1
# 50p 1
# audition 1
# @Stockhausens 1
# scam 1
# Mobitel 1
# tp 1
# biomass 1
# cheering 1
# @Herts1617 1
# PLANS 1
# @PARTYOMO 1
# @Joix05 1
# FAR 1
# anniversary 1
# Blocking 1
# Jake 1
# takraw 1
# circle 1
# They 17
# PIXELATED 1
# Ben 2
# science 1
# http://t.co/n3aIIfaBAP 1
# @Catharine34 1
# naruhina 1
# @missalicebmbds 1
# @SMtajanlangit 1
# shifts 1
# unprecedented 1
# gonna 48
# NSBZHDNXNDAMAL 1
# due 13
# @SaveSxy 1
# born 1
# @toriellis_xo 1
# #Über 1
# looooong 1
# Approach 1
# locate 1
# @Bigbst4tz2 1
# town 4
# would 66
# throat 10
# @TemerickHarper 1
# infra 1
# naya 1
# @ASVPxGABE 1
# tricky 1
# http://t.co/FY8LWoZmob 1
# follback 2
# lives 3
# H 5
# YEYY 1
# WERE 3
# 332 1
# william 1
# bracelet 2
# 9:15 1
# STU 1
# #Shane 1
# http://t.co/oX8G6A4tSj 1
# useless 1
# seem 6
# @electricgujtars 1
# neat-o 1
# consider 3
# https://t.co/bazEmHlhYL 1
# nux 1
# risks 1
# Want 6
# anyway 9
# order 14
# http://t.co/k8uYr8Me57 1
# Pete 1
# elisse 1
# morning 30
# offering 1
# Still 15
# Internet 2
# @flirtyoakley 1
# there's 12
# mr 1
# @ASOS95 1
# PRY 1
# tab 2
# @sannastenman 1
# @tbhnswm 1
# chair 3
# Banana's 1
# @quidco 1
# @tahuodyy 1
# @BrezzyHayter 1
# Berigaud 1
# damnit 1
# @TheLadyShelly 1
# Aus 1
# @CollagenShots 1
# https://t.co/Q5slQJWgDT 1
# @MerlinHousing 1
# @NicolaPantelli 1
# Africa 2
# #imintoher 1
# minutes 4
# @MarzJackson 1
# result 2
# Prima 1
# #summerismissing 1
# mean 28
# iloveyouu 1
# @NUFC_Vine 1
# why 120
# MAKING 1
# chip 1
# biphobic 2
# studio 2
# Nooooooooo 1
# http://t.co/Nvx057PFZp 1
# hardheaded 1
# kinky 1
# . .. 2
# Omg 9
# @LizaNMinnelli 1
# we 113
# lmfaoooo 1
# bts 2
# @lizardbeth_16 1
# GDCE 1
# @edsheeran 1
# polite 1
# feelin 1
# gishwhes 1
# flat 2
# pOPPED 1
# friendly 3
# luke 4
# cookie 1
# chewing 2
# mork 1
# @lucymatthewsss 1
# happen 12
# performed 2
# RN 1
# @RandeepHooda 1
# https://t.co/YcGudITQgx 1
# #ETID 1
# investment 1
# mahirap 1
# Ariel 1
# Classes 1
# bambam 1
# gunna 1
# 11:15 1
# 😬 2
# lah 2
# doesn't 32
# @TomParker 1
# UGH 5
# LOOKING 1
# noone 2
# #SaveTheRohingya 1
# #OTWOLGrandTrailer 4
# pure 2
# artistic 1
# M's 1
# rich 1
# BAE 1
# @jlawrencly 1
# @MrsAnneTwist 1
# discuss 1
# @lucyanne_l 1
# Underrated 1
# utilizing 1
# @Hardlydan 1
# make 54
# nominated 1
# accent 1
# Halo 1
# status 1
# LisaHerring 2
# crop 1
# @satgotlloco 1
# Taco 1
# stereo 1
# @TheScript_Danny 2
# possibly 3
# @Marsaliath 1
# 837 1
# @jaredlovesjen 1
# 1.2 1
# @MitchKinney 1
# motilium 1
# struggling 1
# slept 5
# jersey 2
# health 2
# discount 1
# Kendall 1
# Colin 1
# @hotsootaff 1
# dreary 1
# aisyhhh 1
# eye 1
# meet 24
# @TwilitArgorok 1
# xbsbabnb 1
# Always 2
# month 14
# league 1
# @GabyInTheFields 1
# @mayank_x3 1
# yelled 1
# shan 1
# @HarriDec 1
# @Boybisbored 1
# @marrrrr_13 1
# ITS 6
# replied 1
# leaking 1
# akon 1
# YAY 1
# hahahah 2
# worked 3
# http://t.co/NT25MYnGYd 1
# @MystikGunn 1
# @AmazingPhil 1
# disgusting 4
# YT 2
# http://t.co/ax26wgYdRa 1
# @Jurisprude1 1
# @fionnlim 1
# rolled 1
# #sad 2
# Heathrow 1
# Mixed 1
# (: 7
# backtrack 1
# mara 1
# animator 1
# Baechyyy 1
# LilyButle 1
# ruined 7
# yummy 2
# voting 2
# 2017 1
# https://t.co/KcnI2lMB5J 1
# stocking 1
# noon 1
# @gracegnolo 1
# lyin 1
# @portiatearsbee 1
# Payback 1
# emails 1
# @Lucybanjifede 1
# wouldn't 7
# @LocoTaii 1
# closest 3
# wailay 1
# jail 2
# @OXITS 1
# OUT 4
# 327 1
# centres 1
# @Idamelatim 1
# Jim 1
# Robinhood 1
# ️ 20
# crush 1
# fall 10
# Alive 1
# @staffrm 1
# light 7
# so 466
# Stressed 1
# netherlands 1
# longest 1
# http://t.co/TpZQefeWXN 1
# players 1
# @arthuredmondss 1
# holds 1
# lahat 2
# These 2
# dogs 4
# 😢 8
# x15 35
# @jameswheeler 1
# @Preeti_GG 1
# whyyyyy 1
# briefly 1
# @ED_DURANCE 1
# ruess 1
# stadium 4
# fragile 1
# @OVOEnergy 1
# CONNO 1
# TEARS 2
# @Tanyastan4nicki 1
# fml 4
# fab 1
# men 1
# icing 1
# ohmygod 1
# review 3
# cruel 1
# Etienne 1
# #whyyy 1
# Books 1
# http://t.co/LoMmOjLW1K 1
# by 47
# managers 1
# Elmhurst 1
# TRIED 1
# barkada 1
# Editied 1
# ne 3
# greet 4
# keeping 2
# skate 1
# dandia 1
# buttsex 1
# bhook 1
# @stuartthull 1
# @AireyFlamsteed 1
# extra 1
# WHATEVER 1
# ole 1
# Jacob 4
# @HerFaithness 1
# #ihatesomepeople 1
# support 11
# HAHAHAH 1
# @nathan3205 1
# Coldplay 1
# @Kelsagirl 1
# ache 2
# @WesternDigital 1
# yours 3
# http://t.co/xXfTQWzhAI 1
# @nurseneddy 1
# brainwashed 1
# hays 2
# reminds 2
# parks 1
# @matthaig1 1
# drugs 1
# falls 1
# oh 55
# recording 1
# neglected 1
# none 3
# aswell 1
# @lostboxuk 1
# talk 23
# @RCDeportivo 1
# Princess 2
# house 16
# cleaning 1
# @JoshThomas87 1
# @ipcasongsong 1
# friday 3
# @mzhrkiks 1
# MYUNGSOO 1
# @Debian 1
# try 19
# net 2
# ohhhh 1
# hawke 1
# envelope 1
# OverPerhatian 1
# @aminadujean 1
# gross 4
# @yokotaso_modoki 1
# Brand 1
# nonce 1
# Cinema 1
# @hosongjun 1
# involve 1
# cousins 1
# handle 2
# guilty 1
# YESTER 1
# http://t.co/OiyooLa3GV 1
# Sakho 1
# http://t.co/Ey9MmaSmsd 1
# #hibye 1
# whAT 1
# data 7
# TWINS 1
# @Celestalon 1
# mom's 2
# younger 2
# @davygus 1
# holding 1
# huhuhuhu 1
# orig 1
# 👍 1
# @EXOWORLDINA 1
# His 1
# gundam 1
# 342 1
# infinite's 2
# Whenever 2
# @junghoseoks 1
# @shinthongg 1
# talented 1
# BIRTHDAY 1
# 35 1
# benny 1
# shaa 1
# resy 1
# @CooperativeFood 1
# optimisation 1
# frail 1
# mathird 1
# @monaarcmunoz 1
# num 1
# tie 1
# seasons 2
# design 3
# 07:25 1
# https://t.co/9ixTnyBXLb 1
# ; 26
# @foodiesfestival 1
# Itunes 1
# wishes 1
# serious 8
# JaDines 1
# cant 36
# @halehydruh 1
# dedicating 1
# #kiksex 7
# #Followmeaaron 1
# panic 1
# denim 1
# @clunis_96 1
# twitter 19
# @mooosebloood 1
# previous 2
# noggin 1
# Oo 1
# Forgot 1
# @Nessa_Mbeki 3
# #Tigermilk 1
# @swanqueentacos 1
# 626-430-8715 1
# Monteith 1
# Ally 1
# @MattElyas 1
# 477 1
# @baileymac02 2
# receptionist 1
# College 1
# anything.Surely 1
# 11 4
# aww 10
# groups 1
# sums 1
# http://t.co/5LIiqJqpBt 1
# handsome 1
# http://t.co/U1ZU4OOuxV 1
# schemes 2
# @Ifrahbreezy 1
# pens 1
# namechecking 1
# http://t.co/WfzvRXz1Id 1
# crossed 2
# @RebelGirl1323 1
# hugging 1
# discontinued 1
# #BESTFriend 1
# @golds_indonesia 1
# @Francesca092391 1
# queens 1
# Wag 1
# beings 1
# @subsubjjang 1
# #newmusic 3
# % 8
# confused 6
# Log 1
# They've 1
# gin 1
# duper 1
# @kjmci 1
# episode 6
# @BUTERAIRLINES 1
# smells 2
# Baby 4
# @LlivingDead91 2
# NEW 1
# jumped 1
# @StubsAU 1
# GAAAWD 1
# starts 8
# foiling 1
# @za5 1
# station 3
# joe 1
# thing 29
# gmail 1
# mubank 2
# kme 1
# Having 4
# Max 2
# yun 1
# Twelvyy 1
# 5th 1
# #kiksexting 6
# @jefflacs 2
# @mahhriel_114 1
# mistakes 1
# @ollgbroxei 1
# Just 23
# @AahliyahR 1
# Friendzone 1
# @Engineering006 1
# @swiftlywatson 1
# @JonnyMalee 1
# youuu 1
# Reabsorbtion 1
# flies 2
# MADE 2
# mingming 1
# @elninakauser 1
# lime 1
# old 15
# Today 6
# group 3
# @swiftcarsm 1
# paying 3
# pothole 1
# @cpdigdarkroom 1
# rain 20
# @Espio1 1
# @prattmouserat 1
# seolhyun 1
# Should 3
# @brisbanebroncos 1
# #FightingMCIrene 1
# opened 1
# th 4
# @IsaHurairah 1
# @shayftcolleen 1
# block 2
# champagne 1
# #CP 1
# sleeping 7
# laughing 1
# ve 1
# Soho 1
# http://t.co/CCr5mIKmMZ 1
# @MarielleGeeeeee 1
# @59saniye 1
# @hugeboysmh 1
# Soooo 1
# #addmeonsnapchat 2
# lady 3
# shopping 5
# @jaydebose 1
# @minionicole_ 1
# @tayiscamsbae 1
# remastered 1
# chokkie 1
# wut 1
# mahilig 1
# owner 1
# kind 9
# kiddo 1
# @imVkohli 1
# medicine 3
# UP 3
# online 18
# @Viiiiiiiiev 1
# http://t.co/vlB3nXEDk6 1
# mv 1
# Best 3
# Inner 1
# german 1
# http://t.co/xhdfobhn8N 1
# minute 2
# 9muses 1
# colour 4
# @owyposadas 1
# scheduled 1
# theater 1
# @marjswifter 2
# solos 1
# daddy 3
# wedding 3
# thorpe 2
# quits 1
# ' 55
# all 183
# https://t.co/uYofSgIBVA 1
# tight 1
# @Charliescoco 1
# updated 1
# leaving 13
# fry 1
# @BeardOfTsu 1
# ia 1
# Shamuon's 1
# Prayers 1
# Can 21
# protein 1
# @semo_supercard 1
# @_irwinstagram 3
# @beckparsons1 1
# twers 1
# guitar 1
# vans 3
# @for1rose 1
# Points 1
# waah 1
# @wayhomefestival 1
# Jonathas 4
# NEVERMIND 1
# switched 1
# worries 1
# meds 1
# ganbarimasu 1
# @PMOIndia 1
# http://t.co/XLVw7xaYSi 1
# This 43
# @guptashas 1
# http://t.co/kMrSV4YCz0 1
# indiana 1
# @ulaaaaa1909 1
# because 51
# ShoshannaVassil 1
# pinky 1
# squishy 1
# @AKDP23 1
# @OhPrincessSaRaH 1
# YOU'RE 1
# call 15
# pumps 1
# @russophobes 1
# @obscurro 1
# dresscode 1
# 700 1
# longer 12
# reaches 1
# used 20
# Rick 1
# @bobble 1
# EntlerBountly 1
# dreams 7
# peanuts 1
# NEEDS 1
# AYALA 1
# Cornettos 1
# trying 20
# Whaaaaaat 1
# @VeilBride6 1
# James 3
# safe 4
# recommend 1
# seen 21
# Thoughtseized 1
# Braxton 1
# Really 12
# HWY 1
# dentist 3
# @jackshilling 1
# Eris 1
# sc 3
# @Wapaseeto 1
# path 1
# purchase 1
# @rachaelhussey 1
# mega 1
# Beth 2
# nvr 1
# @JaydnNeal1 1
# Verity 1
# @TheAnimeBible 1
# barely 6
# #Job 1
# WA 1
# freakin 1
# @LushKitchen 1
# Amsterdam 1
# @Apink_2011 1
# bp 1
# pace 1
# @Sakib_ovi 1
# @_SamHernandez_1 1
# Mistake 1
# lactose 2
# ONE 5
# @IamMansoorKhan 2
# Mimi 1
# automatically 1
# alerts 1
# @Ketepi_Ketepi 1
# ver 1
# should've 1
# @lightmytorch 1
# @_Two_Devils 1
# @daftatonix 1
# items 1
# Dota 1
# georgesampson 1
# 9 5
# oooops 1
# http://t.co/LIP80Io2t9 1
# @Virgin_TrainsEC 1
# Injured 1
# x-rays 1
# @nayeou 1
# @bumkeyyfel 3
# sent 8
# melon 1
# strike 3
# ugly 9
# exams 1
# abouty 1
# SEXY 1
# jerk 1
# LIPS 1
# I'm 295
# consistency 1
# Sooooooooooo 1
# SHXBS 1
# laid 1
# supported 1
# eish 1
# OMG 14
# purity 1
# @XIA0HUN 1
# @DotACapitalist 1
# afternoon 2
# DOOMSDAY 1
# movies 6
# drop 3
# nearly 2
# @menilleyble 1
# Paradise 1
# king 1
# @KateWyvern 1
# mixture 1
# RIP 4
# nor 1
# Drop 1
# http://t.co/lk77WR8Rrb 1
# 697 1
# @amazin 1
# information 5
# number 4
# Shame 6
# stayed 2
# cuddles 2
# Ice 2
# http://t.co/t6GAoKfAp1 1
# units 1
# @nickiminaj 1
# @Rinerh 1
# Poooootek 1
# total 4
# Mateo 1
# Indiana 1
# http://t.co/aQzxRk7nk2 1
# @axolotl74 1
# strapline 1
# Life 3
# adams 1
# @ohhhfrances 1
# @ManasRM 1
# @sp1305 1
# @suziepanol 1
# terrible 9
# yk 1
# term 1
# 3:33 2
# Angelo's 1
# keybind 1
# Brilliant 1
# @AisyahZen 1
# computers 1
# @kylaholiver 1
# pegea 1
# Y'all 1
# expecting 1
# novel 1
# NOT 12
# IS 9
# it'okay 1
# @tashaxptv 1
# READY 2
# #fxhelp 1
# GIVE 1
# #Kinara's 1
# government 1
# Zaz 1
# tayo 1
# @irlfaker 1
# prey 1
# manbearpig 1
# @MattJackson13 1
# PARIS 1
# understandable 1
# feeling 30
# jackets 1
# Tweetin 1
# 320 1
# learned 1
# dur 1
# READING 1
# AAAAAHHHHHHHH 1
# @colon_valeria 1
# http://t.co/Nu0PMyGKU9 1
# weekend 22
# @denocte 1
# plays 3
# nuclear 1
# anyways 3
# snot 1
# Dallas 3
# IMPORTANT 1
# collar 1
# whyyyyyyyyyyyy 1
# urgh 1
# postie 1
# https://t.co/ApJ18ZWK0x 1
# http://t.co/3S9LHaFrsU 1
# balloon 1
# SOUNDS 1
# @MakeYouKnowLove 1
# https://t.co/wt4oXq5xCf 1
# believe 14
# @dnwrld 1
# lunes 1
# Islands 1
# knowing 2
# #elfindelmundo 2
# sneaking 1
# 100k 1
# #2fm 1
# Greece 2
# @THE 1
# http://t.co/00YckcE7wj 1
# Egypt 1
# @GrumpyCockney 1
# http://t.co/0bcvA6YjWu 1
# 🎉 3
# birthday 22
# there 83
# burned 3
# 🐒 1
# defensive 1
# #WindowsPhone 1
# @burgeeem 1
# NG 1
# celebration 1
# chat 4
# @SUGGLEEET 1
# 11:25 1
# @YouTube 7
# Smh 1
# @Kellipage17 3
# @amk 1
# @changkyunaf 1
# @Gavin_McInnes 1
# Leno 1
# @simonshieldcars 1
# senior 1
# 2013 1
# deantd 1
# Uber 1
# pining 1
# AmargoLonnard 2
# @henryholland 1
# Anybody 1
# https://t.co/rWEjE5uOjg 1
# sweedy 1
# Wrecking 1
# GROTTY 1
# CC 1
# knw 1
# drank 1
# misserable 1
# @WaseemBadami 1
# #nsfw 1
# maine 1
# #ISIS 1
# banged 1
# @_ainzuhraa 1
# ELF 1
# Spain 4
# @soL_Lyah 1
# http://t.co/QouW0Uwd8O 1
# gladly 1
# Why 45
# https://t.co/C0zXMuWeM1 1
# you 660
# lurgy 1
# noticed 2
# @aquazzSky 1
# bubble 1
# 2.5 1
# http://t.co/lR3JUxPtJG 1
# friend 14
# al 2
# dairy 1
# Uff 1
# saaaad 1
# 12 8
# haestarr 1
# #lgbt 3
# kirkiri 1
# sex 2
# funk 1
# hiding 1
# #TURKEY 1
# nooooo 1
# @WLK_SNaeun 1
# @ROOM94 1
# @unclutching 1
# 7.30- 1
# office 7
# bomb 2
# 22nd 1
# download 1
# 40 3
# invalid 1
# Casillas 1
# somebody 1
# Nemanja 1
# PERF 1
# Do 8
# Math 1
# Inc 2
# http://t.co/l99IanEBsi 1
# Jongdae 1
# @gabriel_platon 1
# hbd 1
# organization 1
# @myoddballs 1
# testing 1
# seniors 1
# @AmeAmeSakura 1
# Mady 1
# easily 2
# flight 6
# ´ 4
# finale 2
# @TheOGB 1
# bloopers 2
# complained 1
# jahat 2
# https://t.co/H8nYlHaQOo 1
# Practice 1
# TL 2
# @BillieJoeSpouse 1
# kick 1
# WHERE 2
# eunji 1
# crime 1
# faith 2
# every 14
# Eh 1
# #interracial 3
# suan 1
# 345 1
# @S1dharthM 1
# Laper 1
# http://t.co/Lh5sNTHmIV 1
# with 172
# freed 1
# probably 8
# beasts 1
# pathetic 1
# richard 1
# boss 4
# hr 1
# zzzz 1
# joking 4
# z 4
# relatives 1
# akana 1
# #unloved 1
# mass 1
# realise 4
# shame 13
# @Muselshoux 1
# #bblf 1
# 76 1
# @jxhun 1
# @JodanasandyXx 1
# project 1
# 15-24 1
# overall 1
# PRICE 1
# Rejection 1
# @AnnieIsDoomed 1
# badly 12
# @ameliahartin 1
# Handsome 1
# Kylie 1
# #FridayFeeling 1
# #Finance 1
# @kyuzizi 1
# Macedonian 1
# nagbabasa 1
# wahhh 1
# 316 1
# Boah 1
# @betabetic 1
# # 16
# @MatthewLush 1
# @charlotte_louth 1
# sell 6
# @EE 2
# APOLOGY 1
# wasp 2
# seeing 15
# stans 1
# AstonVilla 1
# @KristyBookNerd 1
# Mission 1
# relive 1
# Nintendo 3
# @elglozano 1
# @sam_mcclure 1
# shes 4
# sheriff 1
# #stafford 1
# IM 14
# Skye 1
# #SleepDeprived 1
# convince 2
# youtu.be/2_gPcTSojKw 1
# rules 1
# HAVE 12
# dept 1
# php 1
# http://t.co/HlnZzdW0Tz 1
# ginge 1
# @Rico_Shabbir 1
# @robinpatrickm 1
# network 3
# pool 1
# doedn't 1
# http://t.co/Izhrf94jnB 1
# Feeling 5
# litro 1
# @LaEtchi 1
# Hnnnnnnn 1
# offers 3
# @ImHibaNoor 1
# virgin 1
# Everyone 3
# Marvellous 1
# http://t.co/wInJbEhRq1 1
# Hahahaha 1
# spectator 1
# out 114
# Panic's 1
# theyre 1
# care 14
# @fawadchaudhry 1
# uber 2
# shaaaa 1
# influenced 1
# Juja 1
# kailan 1
# grans 1
# @bemeapp 1
# would've 2
# Church 1
# NM 1
# im 93
# #Misundersranding 1
# @mustntgrumble 1
# door 4
# ा 2
# EVERYTHING 1
# @JacobAndrade33 1
# @bezz100 1
# chokes 1
# ON 3
# jen 1
# Project 2
# x 33
# http://t.co/kQWxO527tb 1
# clip 1
# envy 1
# diary 1
# @TheUselessThree 2
# ordering 1
# #NathanielHinanakit 1
# interview 2
# tsktsk 1
# #TBT 1
# mune 1
# vegetables 1
# creep 1
# qualified 1
# MCountdown 1
# ask 10
# pledge 1
# am 88
# @AdaptsTheGod 1
# https://t.co/JZBFBKld8Q 1
# Matthew 1
# tub 1
# https://t.co/Q5TAYjrQ8K 1
# @mikeyyfontt 1
# http://t.co/4OU2EyPh8A 1
# yepp 1
# mid-end 1
# noodles 1
# role 1
# fuckboys 1
# creds 1
# irresponsibly 1
# @DayveHallam 1
# http://t.co/0UvPRQnvGl 1
# Burberry 1
# ran 5
# See 3
# @pickledog47 1
# Shark 1
# @Suzy_slutcake 1
# truckloads 1
# waited 1
# El 1
# waters 1
# @_mspxo 1
# afterschool 1
# junior 1
# Parents 2
# severely 1
# http://t.co/z0a6jTboH8 1
# koalas 1
# Saras 1
# what's 11
# @kennyfairley 1
# SMTM 1
# @vedant_ag 1
# Verfied 1
# lage 1
# @devoncarlscn 1
# eyed 1
# You 26
# Using 1
# @Cro_Marta 1
# @_lizzy_kay 1
# GYU 1
# ZAP 1
# namin 1
# @mariaebun 1
# receiving 1
# French 1
# story.Miss 1
# weeks 13
# assignments 3
# @hejgordon 1
# http://t.co/ajZLTdCzI7 1
# @destinydatabase 1
# @MagandiaAdjrani 1
# I'll 30
# wraps 1
# rattle 1
# burnt 2
# t'existes 1
# 404 1
# ALWAYS 6
# https://t.co/9ojA3FPxKF 1
# haizzz 1
# Ah 7
# passport 1
# WEARIG 1
# dunwan 1
# whyyyy 1
# @ColorsTV 1
# IT'S 6
# @PraiseKINGDAVID 1
# likee 1
# Watch 1
# d1 1
# waduh 1
# Flying 1
# appendicitis 1
# over 44
# @AzamaraVoyages 1
# teacher 1
# mobile 2
# Suits 1
# store 3
# http://t.co/qEV0hix7JZ 1
# .
# . 2
# HOME 1
# Thoughts 1
# someday 1
# Great 5
# @TonightAlive 1
# @amnesiall 1
# lunch 6
# @FATMA_TEARS 2
# Pray 3
# mene 1
# MAYMAY 1
# #kikhorny 13
# karin 1
# msgs 1
# Elgato 1
# @MojangSupport 1
# effect 2
# toast 1
# giriboy 1
# shuffling 1
# 10.3 1
# accurate 1
# xbox 2
# Chel 1
# http://t.co/2HnzstgnOa 1
# h8 1
# wear 3
# EH 1
# GRAY'S 1
# Anything 1
# @BlatBlatKLANG 1
# @StreetFighter 3
# @sxnflame 1
# EDOMNT 1
# http://t.co/fACJpi5F3p 1
# @beigemarauder 1
# soundcheck 1
# Happily 1
# Rupert 1
# @MaddyyOR 1
# guinness 1
# @Marguuuuh 1
# Hyungwon 1
# pictures 6
# crowd 1
# Wew 1
# WINGS 1
# democracy 1
# @jperkovic93 1
# @kingsxcreed 1
# baggage 1
# https://t.co/poglAQg9sJ 1
# Tasteless 1
# announcements 1
# speaking 1
# sirf 1
# heyy 1
# 26th 1
# @7essycaauryn 1
# HAHDHDHSHHS 1
# @sadcuddleashton 2
# hinde 1
# #SYRIA 1
# ...
# poorly 5
# http://t.co/RJBAFfSMbh 1
# dick 4
# Once 2
# Alex 4
# DCI 1
# chill 4
# wheel 2
# HAHA 1
# @0PlATE 1
# @BestBedrooms 1
# suspended 2
# bathroom 1
# 346 1
# Barcelona 2
# HONEST 1
# bothering 1
# hates 2
# drained 2
# Bull 1
# maybe 21
# Hard 1
# interest 5
# EXPERIENCED 1
# Gamescom 1
# 🚙 1
# NicoleaPage 1
# amount 2
# lunches 1
# Fabian 2
# FC 1
# less 2
# @donhutch4 1
# @drewsdimple 1
# THIZ 1
# @GalwayIntArts 1
# Didn't 1
# distance 2
# @Darlene_Vibares 1
# Roma 1
# Pier 1
# @jiministic 1
# GAME 1
# 🎈 1
# Updated 1
# can 117
# @Starbucks 1
# percentage 1
# sew 1
# @CBuchanan68 1
# St 1
# sunburnt 1
# langs 1
# Shite 1
# / 54
# off 41
# @brenttiscool 1
# @borapls 1
# @clementine_ford 1
# trees 1
# #PDApaghimok 1
# Bestfriend 1
# insecurities 1
# STAGE 2
# who'd 1
# 6:15 1
# @antichankai 1
# twisting 1
# Pains 2
# Vine 2
# @StevensSlateCo 1
# pliss 1
# @wendykims 1
# @Rossi_mac9306 1
# esteem 1
# typos 1
# respect 3
# maganda 1
# whatsapp 1
# up.Come 1
# seatmates 1
# Ami 1
# ding 3
# #edm 1
# @Cour98_x 1
# nuggets 2
# Chelsea 1
# 1d 1
# @BloutAngelina 1
# mirror 1
# Found 1
# http://t.co/b3qkLaFJx4 1
# hitting 1
# zoomed 1
# @Ch4rm41n3 1
# ramzan 1
# dinner 4
# que 1
# breakups 2
# Labour's 1
# @ayoo_gerry 1
# servers 1
# Montana 1
# @Uber_Chennai 1
# @QuetaAuthor 1
# playables 1
# 5:15 1
# Councillors 1
# @janellearg 1
# @MassDeception1 2
# seemed 1
# @kewlaf 1
# 12.00 1
# http://t.co/iWAeDmuooP 1
# duck 1
# @SP3CTACL3S 1
# @GlastoFest 1
# Finnair 1
# @Rhianne_97 1
# sholong 1
# gotten 1
# set 9
# short 8
# rib 1
# yelaaaaaaa 1
# price 1
# @Morteraaaaa 1
# 💋 2
# lure 1
# shor 1
# striker 2
# within 3
# Kian 1
# Cory 1
# gorgeous 1
# @twinitisha 1
# Rantie 1
# Odoo 1
# leh 1
# Pyaari 1
# rlly 2
# http://t.co/wN3169K7Kb 1
# whips 1
# vips 1
# @Julia886 1
# streams 3
# lootcrate 1
# HES 1
# https://t.co/Hgr1dMQ1eQ 1
# Slovakia's 1
# Cuddling 1
# poor 25
# @namwngr 1
# it'll 3
# deserved 1
# Struggling 1
# negotiate 2
# LA 3
# disc 1
# curtain 1
# models 1
# cut 13
# SORRRY 1
# deactivated 3
# Ed 1
# http://t.co/RZ52EUtzMD 1
# #blowjob 1
# come 54
# @emshelx 1
# derp 1
# http://t.co/QFtLZ2Cl0w 1
# training 6
# afterbirth 1
# @mattyelvin11 1
# inspirit 1
# doctors 1
# https://t.co/Ifwuz7Wl5j 1
# pret 1
# #Admin_Myung 1
# @Solo_Dm_Helperr 1
# kitkat 1
# program 1
# @JayMcGuiness 16
# Cotton 1
# bleeding 1
# esnho 1
# F1 1
# FCKING 1
# experiencing 1
# @walesdotcom 1
# full 14
# lack 1
# @sunggyu_ph 1
# Gay 2
# dormtel 1
# #MCFC 1
# SeungChan 1
# @_ajaaaa 1
# RUN 1
# talking 12
# Eugh 1
# Jdjdjdjd 1
# particular 1
# Take 4
# heaps 1
# visits 1
# @ilykmh 1
# @sneaksontaylor 1
# Me 9
# #wewanticecream 1
# picks 1
# @HeyyLawley 1
# @_Milli__ 2
# unique 2
# calls 7
# village 1
# @luvsgngrhd 1
# merch 2
# caramello 2
# schedule's 1
# Steel 1
# proposal 1
# Open 1
# realistic 4
# #selfshot 2
# @njhftbiebs 1
# mushroomed 1
# fortunes 1
# Say 1
# @hausofbekah 1
# netball 1
# telling 4
# throw 2
# candy 2
# @Cupcake_XGN 1
# Crack 1
# ni 4
# Viners 1
# Jack 2
# machinery 1
# https://t.co/hb7eR51JdX 1
# bullshit 1
# inte 1
# drain 1
# initial 1
# wiper 2
# @revivalcth 1
# @imaginIarry 1
# flowers 1
# answers 2
# HUHUHUHUHU 1
# hushed 1
# tumour 1
# avail 3
# @Charalanahzard 1
# @iamrrr 1
# buys 1
# woes 1
# Pleasure 1
# sorka 1
# complain 1
# nurses 1
# pleass 1
# #RespectLost 1
# A9 2
# Wasn't 1
# choppy 1
# bathtub 1
# @jeffweiner 1
# 💖 4
# @bsuzysk 1
# earlier 9
# robbed 1
# failed 7
# thirstyyyy 1
# forever 10
# cream 30
# @LouiseMillerx 1
# @ZappingZach 1
# @MollettGames 1
# baek 1
# ear 3
# udah 1
# http://t.co/4gbLRYagWh 1
# 20mins 1
# TAKE 1
# sinse 1
# She's 4
# @LiLGeekette 1
# Dubai 3
# Sterling's 1
# 😀 3
# shek 1
# @NeilMorganGtr 1
# @Hafeelalala 1
# AM 8
# bed 12
# inside 8
# http://t.co/KkPDlQZ2F4 1
# #kissme 1
# #newbethvideo 1
# DAYS 3
# often 1
# partner 2
# Expedia 1
# #Bad 1
# @darrenwho_ 1
# sucky 1
# grepein 1
# Hiya 1
# describe 1
# Police 1
# @SnellingD 1
# @subharrie 3
# BUST 1
# @literalwt 1
# Short 4
# parrot 1
# @VictoriaParkBks 1
# wide 2
# @Giannivnni 1
# #CalibraskaEP 2
# hacked 6
# http://t.co/nwriRgSq8v 1
# colombia 1
# foood 1
# awwwwww 1
# spick 1
# bi-polar 1
# relaxes 1
# #poorKid 1
# LATE 1
# stoop 1
# draking 1
# @ComfyCooCoo 1
# 2:30 2
# ends 4
# 7-3 1
# @TheShoeBibles 1
# old's 1
# nice 15
# dark 4
# South 2
# bread 2
# rodFanta 1
# yelling 1
# ericavan 1
# viathe 1
# @ASUS_ROG 1
# lush 1
# met 6
# Chill 1
# physically 2
# busy 26
# Mensch 1
# details 1
# @kaylakerwin 1
# anythin 1
# girlll 1
# #givecodpieceachance 1
# @iFazy 1
# dyed 1
# https://t.co/LeL2yOp3Iq 1
# @perriesjades 1
# reckon 1
# hais 1
# emptier 1
# Star 1
# #ShareYourSummer 1
# developed 1
# Patch 1
# #matteroftheheart 1
# sir 4
# yeke 1
# quickest 2
# choreo 1
# ✈ 2
# arm 2
# @iviecrystal 1
# _ 22
# awning 1
# http://t.co/WHJfmcRZWX 1
# 1ly 1
# social 1
# Фотосет 1
# hub 1
# @twyodor 1
# 2 43
# https://t.co/GP21Mwg1Os 1
# Adidas 1
# lmbo 1
# originally 1
# scared 15
# migrant 1
# investigate 1
# @nickjdrake 1
# ITB 1
# Comfort 1
# story 11
# @horanshan 1
# dispatch 1
# @Farrahnair 1
# @Johnny_Spacey 1
# @halfmoonhalsey 1
# 2am 1
# eyesight 1
# Showed 1
# #PARTY 1
# callllllls 1
# http://t.co/s5Dw4o9nvb 1
# fOllow 1
# https://t.co/nJ0ziQ14is 1
# Indonesia 1
# @neikmat 1
# @leighannajohns1 1
# Beach 3
# #omegle 4
# @cragdoo 1
# bin 1
# @romanhloiday 1
# if 84
# spray 1
# sayanggggggggg 1
# @Titus3D 1
# rooting 2
# prisssss 1
# bapak 1
# 4am 1
# whyyy 1
# tracks 1
# @Cas_Audio 1
# @IzzyTailford 1
# racing 2
# word 6
# lay 1
# @Tanithandicraft 1
# assignment 1
# sana 2
# acoustic 2
# mammoths 1
# @_nurannisaaa 1
# @zoellaftmendes 4
# @s0ulfl0wr 1
# फ 1
# 322 1
# they're 10
# http://t.co/GKFgw0Khy6 1
# @sophiescott 1
# nw 1
# @BEINGASANOCEAN 1
# @Skulker_PoA 1
# @hankgreen 2
# Sanum 1
# http://t.co/7Hal7PTTAN 1
# hungrrrryyy 1
# Manush 1
# rat 3
# miracle 1
# finals 2
# figure 1
# @dugganrachel 2
# sehun 1
# Real 4
# twurkin 1
# indicated 1
# tams 1
# 765 1
# @ceeels95 1
# Support 1
# Man 7
# flew 2
# @AllicioGloria 1
# @_CaitlinTierney 1
# 87.7 1
# baechu 1
# flags 1
# rumpy 1
# DEACTİVATED 1
# upon 1
# LeanneRiner 1
# Selenators 1
# railway 1
# laced 1
# than 32
# @DeviousLiz 1
# election 1
# grrrr 1
# couples 1
# http://t.co/Dn6agZcPhd 1
# @nuttyxander 1
# cries 2
# mutilated 1
# Finishing 1
# timing 4
# goddamn 1
# Mexico 2
# offline 1
# mm 1
# brought 1
# @bttrcpxljp 1
# purple 1
# http://t.co/hgE3nNSq4q 1
# Kanin 1
# ummmm 2
# dost 1
# @iainbruce 1
# Goodafternoon 1
# nadalaw 1
# com 1
# moodboster 1
# @QjQj_Kwon 1
# #bb17 1
# dislike 1
# shouldn't 1
# Completely 1
# @BillyNeyMates 1
# fighting 1
# absolute 2
# Cody 1
# jeon 1
# apartement 1
# Finding 1
# http://t.co/4iBT7zCjZH 1
# Kevin 1
# nawf 1
# orang 1
# style 2
# @asos95 1
# http://t.co/VcRhaDOqPt 1
# 328 1
# kennel 1
# gidi 1
# Fk 1
# @Madtloves 1
# pup 1
# Idk 4
# heartburn 1
# nights 2
# @Wolf_Stack 1
# cities 1
# Sinhala 1
# us 40
# uu 1
# 544 1
# @seunjinbing 1
# ? 644
# nasty 2
# Evening 1
# From 2
# watchdog 1
# #JabongatPumaUrbanStampede 2
# Australia 2
# omigod 1
# https://t.co/naDYZSJbca 1
# @ljam185 1
# extremely 3
# skyfall 1
# @ItsFoodsPorn 1
# @choivernope 1
# letting 4
# #naked 1
# Rejected 1
# memorization 1
# 18C 1
# surprise 3
# delivery 3
# hua 2
# moment 13
# WITH 3
# Pero 2
# @jhezreenmae 1
# @LaveeKaif 1
# Christmas 1
# @kmubmik 1
# posts 2
# workin 1
# periscope 1
# @loyalistofSoShi 1
# KNEW 1
# understands 1
# PLAY 1
# crackling 1
# toneady 1
# across 4
# become 4
# Difficult 1
# sugar 3
# Apple 3
# @ItssssKelseyyyy 1
# hurry 3
# AN 2
# bless 2
# @ddlovato 1
# @davidgold 1
# concerts 2
# Muslim 1
# justice 1
# @dethronedlwt 1
# IKEA 1
# San 3
# demn 1
# hellish 1
# CANT 5
# @Ohioleh 1
# hyungwon 1
# 10th 1
# Selangor 1
# http://t.co/jjSI8VScPL 1
# Ernie 1
# @Blush_Channel 1
# fuck 18
# search 3
# @1paintology6 1
# lifetime 2
# @SOLODMHelperrs 1
# orchestra 1
# @carouseldiary 1
# @pooj_ 1
# @makalamerry 1
# @hallashi 1
# @1057darwin 1
# kepo 1
# dead 9
# @pamtravel 2
# rted 2
# bff's 1
# Backed 1
# unfollows 1
# basara 1
# @msnbc 1
# @sick_fruits 1
# wtfff 1
# Hopefully 5
# Shackell's 1
# agencies 1
# P 4
# subway 1
# khatam 2
# 150-160 1
# aaaaaaaaaaaaa 1
# BAD 3
# sorta 1
# expected 1
# Stockholm 1
# ones 5
# outta 1
# Eric 1
# ✧ 8
# @DMisHaram 1
# UNPARENTS 1
# @woIfgaang 2
# @halle182 1
# @tokyato 1
# app 12
# @neillcameron 1
# @Velocentric 1
# alot 1
# Capeee 1
# @Hyojinsshi 1
# @SEOLMDR 1
# @mynba2k15credit 1
# @ScriptedOne 1
# @katjturgoose 1
# Hell 1
# @bbomiyeh 1
# pic 9
# http://t.co/Xl6kKYUbk3 1
# drive 9
# brows 1
# @KelseyjRenwick 1
# cocktaily 1
# Jaya 1
# bench 1
# @EvokeToday 1
# @ecclestech 1
# speak 3
# gates 1
# hahaha 7
# @dayaxo 1
# panda 1
# ✔ 1
# #family 1
# @bcwgaming 1
# Cup 1
# @DJRyanHemsworth 1
# et 2
# camps 1
# @cloverness 1
# awhile 2
# marketing 1
# stable 1
# @Please_like_me 1
# 331 1
# @kendrahatesu 1
# 1.8 1
# @APluckyHeroine 1
# @carterreynolds 3
# @kwangqiiii 1
# bottle 3
# @bluexxdream 1
# @DC_krystal94 1
# VERY 1
# sitting 2
# cyber 1
# prods 1
# hit 4
# Sebastian 1
# neh 2
# request 2
# friooooo 1
# appear 1
# 4 18
# tall 2
# missed 27
# @deepikapadukone 1
# dd 1
# cope 3
# next 37
# @_Birexus 2
# higher 1
# ion 1
# @leesasana 1
# @JamesEllwood0 1
# #hot 2
# @Team_AjayDevgn 1
# ishii 1
# @CMPunk 1
# accidentally 1
# Donna 1
# yo 4
# Imma 1
# relate 1
# offroading 1
# fever 5
# county 1
# #AFLBluesHawks 2
# specific 2
# @Quality_CE 1
# @austinh_44 1
# #mybrainneedstoshutoff 1
# watched 3
# older 5
# ores 1
# zoo 1
# kits 1
# bloating 1
# @vivalabeat 1
# bakit 3
# @jadehaines 1
# @DatMelvin 1
# @TheOnlyRazzYT 1
# pollution 1
# http://t.co/vEy02VcNGs 1
# Youre 1
# hopia 1
# @GiGiHadid 1
# Serbia 1
# cramps 2
# @KimIannucci 1
# willy 1
# buying 1
# killers 1
# view 6
# pinay 1
# pal 1
# @MollysBarWOMAD 1
# transmission 1
# @aula_jr 1
# twin 1
# EDITING 1
# pee 2
# noooooooo 1
# tseba 1
# concert 9
# brother 7
# TAYBIGAIL 1
# masterchef 1
# @imarieuda 1
# @keancipriano 1
# beyt 1
# colleagues 1
# unfollow 4
# dragging 1
# recuerda 1
# talent 1
# on 297
# single 10
# Warrior 1
# chem 1
# #thestruggleisreal 1
# mani 1
# CHILD 1
# sare 1
# Blackberry 1
# yess 2
# Mommy 1
# tlists 1
# http://t.co/8aOe100cdC 1
# to 1068
# @Israelgirly 1
# dad's 1
# digits 1
# system 3
# finger 3
# @pennystocksusa 1
# Sidharth 1
# #jaspernationalpark 1
# Gardening 1
# Sodders 1
# @peterpalmer52 1
# does 14
# delay 3
# Trying 5
# massages 1
# yumu-youtuber 1
# subtitles 1
# deal 6
# @topcoder 1
# http://t.co/zEQNiFVHUT 1
# pad 1
# counts 2
# http://t.co/uVJzARE3tp 1
# Civ 1
# ruining 1
# brad 1
# #Lazy 1
# @xcrazy90skidx 1
# @marlenejazmyne 1
# appendix 1
# @someboysjumper 1
# #AlDub 1
# hogo 1
# @moontwink 1
# @headlinepg 1
# @often_partisan 1
# #Stexpert 1
# bastard 1
# numbers 1
# Wednesday 3
# how 78
# TONIGHTS 1
# Clarke 1
# therefore 1
# @GZTAEHUN 1
# @Habib_Insyaf 1
# @Puddycats19 1
# stuff 11
# wont 9
# Aigooo 1
# http://t.co/D0W4ts9l2l 1
# church 1
# humse 1
# robs 1
# quetiapine 1
# http://t.co/sxeh7LUH4q 1
# Delhi 1
# bakwas 1
# @NRL 1
# sometimes 8
# http://t.co/2BHfR9BU26 1
# @camss59 1
# grounded 1
# cupcakes 1
# deosn't 1
# Vehicles 1
# @SensodyneIndia 4
# mah 2
# lipstick 1
# Video 1
# football 3
# @ljenkins314 1
# concept 3
# gif 1
# boong 1
# @KyraaVazquez 2
# side 6
# Cooper 2
# #deathbybaconsmell 1
# zero 1
# HAHAH 1
# Lart 1
# México 1
# @filadelfiaaa 1
# soulmate 1
# cable 1
# 46532 1
# @TheChelseaTalk 1
# @1010hoshi1010 1
# exhausting 2
# teasing 1
# http://t.co/7JhaSTESp8 1
# POOOOOOOOOR 1
# SECTION 1
# 1st 3
# @erinaree 1
# longe 1
# dae 1
# propa 1
# fear 1
# untouched 1
# adult 2
# irony 2
# bruh 3
# armor 1
# OL 1
# fr 2
# jeans 2
# both 13
# danceeeeee 1
# start 20
# SRSKY 1
# whistle 1
# FOOT 1
# @st3cav 1
# @fabssulli 1
# @JacobWhitesides 2
# Stop 2
# BELİEVE 35
# pizza 6
# @MelanieLBBH 1
# https://t.co/16pOubmvlX 1
# giving 3
# @DiganganaS 1
# losers 1
# @__onlynay 3
# @MyNamesChai 1
# baby 36
# @KOVENuk 1
# @martinamegia_ 1
# http://t.co/pNq95QKn9G 1
# @RohYB_ 2
# Ahmad 1
# children 1
# @nashyy_niall 1
# Perhaps 1
# @ShahidsSuperFan 1
# emergency 1
# @RNLI 1
# burning 1
# reaally 1
# happy 23
# misspelt 1
# genesis 1
# service 2
# @EllieWalker_1 1
# @3Yorkshireteers 1
# FR 1
# la 7
# #love 1
# SD 1
# Accurate 1
# refollow 1
# Wetherspoons 1
# browsers 1
# @ShanduLinda 1
# @luannesorrell 1
# http://t.co/nzQmWYMw2b 1
# Sara 1
# #girls 1
# Bullshit 1
# rent 2
# thoughts 1
# @ajaydevgn 1
# wipe 1
# dry 1
# event 2
# @Penguin_porter 1
# #danzell 1
# crashing 2
# TERRIBLE 1
# clients 1
# California 1
# I'd 8
# bheyps 1
# @HoldyHoldy 1
# nothing 23
# @1DInfectionMNL 1
# okie 1
# Parasyte 1
# luck 5
# ph 1
# kats 1
# investigations 1
# hats 1
# @JoUllah 1
# #calibraskaEP 1
# dancer 1
# guy 8
# Matt 1
# pmsl 1
# HTML 1
# https://t.co/gaWf0bsr6A 1
# sacconejoly's 1
# NEED 3
# wth 2
# cute 34
# ty 1
# @OfficialCK2013 1
# @DaVincis_Starz 1
# http://t.co/OVU4p2qWfH 1
# Hope 19
# bunny 1
# one's 1
# dies 2
# @PhoebeBooks 1
# unfollowing 1
# breaking 2
# bored 10
# lighting 1
# tittheir 1
# rub 1
# @CHONIM91 1
# @athiraidrus 1
# 5h 1
# #geek 1
# @SarahRashadd 1
# 20 13
# @PaulHollywood 1
# RBI 1
# feverfew 1
# joined 1
# someone 49
# Complete 1
# @RyanCooperXZ 1
# external 2
# proper 2
# @WizKhallista 1
# @oIiverfelicitys 1
# wong 1
# either 13
# ँ 1
# breaks 1
# received 6
# tagged 1
# mcnuggets 1
# @PexDesigns 1
# softball 1
# WHDJWKSJA 1
# sulli 1
# Omfg 1
# Gaga 1
# promo 1
# wig 1
# goTDAMN 1
# http://t.co/7xyNmimTpR 1
# lab 1
# waffle 1
# edition 1
# … 18
# launched 1
# Bush 2
# Spent 3
# isn 1
# @HAMEZR10 1
# @lana___amiir 1
# knee 2
# @guevarawr 1
# streaming 4
# thingy 1
# @inathancameron 1
# especially 2
# goal 3
# #lungomare 1
# doujin 1
# @Jakers787 1
# b8 1
# thirsty 1
# trick 2
# swag 1
# https://t.co/R6HhQ0lE5p 1
# meh 3
# inconsiderate 2
# @bravefrontiergl 2
# #booty 1
# http://t.co/T9rpuLyb5u 1
# #zayniscomingback 3
# Yaadein 1
# CHEM 1
# Krystal 1
# Bahay 1
# kingdom 1
# @ianrobo1 1
# ShirleyCam 1
# Sr 2
# bethesda 1
# CAN 6
# cupid's 1
# @Excluzzive 1
# MARGO 1
# Shocking 1
# https://t.co/kA6V6VIANv 1
# stabbed 1
# @ChocolateCharsi 1
# @leighalexander 1
# suks 1
# facebook 3
# @_allypasturan 1
# #sniff 1
# @corbynjokes 1
# @Raaderer7 1
# edit 1
# development 1
# thát's 1
# Petaling 1
# THANKS 52
# ♛ 210
# @ShaunySoda 1
# he's 20
# 27 1
# @myungfart 3
# @bmthofficial 3
# #BuyNotAnApologyOniTunes 1
# daft 1
# @aiifanadhirah 1
# leave 24
# @marie_apayor 1
# @Nebula2592 1
# emotion 1
# claimed 1
# Lunch 3
# JannyGreen 2
# Laughing 1
# #tagsforlikes 5
# wii 1
# 7DF89150 1
# @craigyboi 1
# afghanistn 1
# @BritishSignBSL 1
# everyday 7
# bb 5
# soggy 1
# DIDNT 3
# huhuhu 2
# Friday's 1
# roar 1
# @AA12YT 1
# IK 1
# migraine 2
# MIA 1
# BEING 1
# pale 2
# @oreaux_ 1
# daianerufato 3
# LOW 2
# abligaverins 2
# hawk 1
# @taoya_suzaku 1
# http://t.co/FplKjpXNQN 1
# @againstmisogny 1
# Missyou 1
# swell 1
# @smiffy 3
# @jonathan_wolle 1
# kaha 1
# hubby 1
# @rxpstar 1
# tim 1
# pray 5
# party's 1
# glasses 3
# 🌞 1
# Ode 1
# @CrazyGreen16 2
# fluffy 2
# Ledger's 1
# Hahaha 1
# @Xjenrobinson 1
# thanks 14
# troubles 1
# @anj100 1
# purty 1
# http://t.co/NNEeBaoTVY 1
# stairs 1
# @nateworkorange 1
# @kbreeezy__ 1
# bad 58
# @Rosiejanele 1
# @emergingrecruit 1
# #woman 1
# Zante 1
# @hfaithdavis 1
# mince 2
# presentation 1
# printer 1
# saklap 1
# very 44
# weave 2
# messenger 2
# @Ben_Barker1989 1
# nate 2
# 🍜 3
# montana 1
# Mumbai 1
# DUTY 1
# @gadventures 1
# Swedish 1
# Scheduled 1
# Kyle 1
# @zaynmalik 9
# chara 1
# @cosplayamerica 1
# FIFTH 1
# functions 3
# cs 1
# RUMOR 1
# xxxxxx 1
# Jealous 2
# @sakuraflower20 1
# whole 16
# layout 2
# 👑 1
# Kong 1
# drawing 2
# @AMYSQUEE 1
# Fagans 1
# Kuchar 1
# 8.40 1
# 11am 1
# 1000 1
# #ausfailia 1
# @MollyRosenblatt 1
# sunrise 1
# max 1
# trafficking 1
# @CalderClarion 1
# tonsillitis 1
# Look 1
# #like4like 5
# pll 1
# https://t.co/3FsrYukgt4 1
# Almost 2
# Sent 1
# https://t.co/glBmiAAJ79 1
# Glue 1
# #t20blast 1
# sigh 8
# https://t.co/R1Sbnpovdg 1
# unable 2
# 。 3
# How's 1
# @KyuminpuVELF 2
# Expired 1
# nachos 1
# Xoxoxo 1
# @mishacollins 1
# @sinSALEM 1
# http://t.co/uNorqB0mlK 1
# Who 2
# magcon 1
# such 26
# http://t.co/3BRNMai3CU 1
# leaves 2
# compete 1
# @Kingstxnn 1
# http://t.co/EC1zF7A9sy 1
# @ConnorFranta 1
# nameeee 1
# Hate 6
# stressful 2
# waale 1
# harsh 2
# allergic 4
# blaaaaze 1
# @cutelikejdb 1
# @Zearify 1
# leader 1
# @rinshilah 1
# Kimaaaaaani 1
# http://t.co/gYw0ckFKhR 1
# http://t.co/stdLTH1PBS 1
# step 2
# yulin 1
# @jaybutcher 1
# luckyyyy 1
# @LordOfTheMics 1
# @ODIHQ 1
# inuyasha 1
# damn 24
# @KapitaineRose 1
# @PlanetRockRadio 1
# touch 4
# ☺ 3
# clandestins 1
# okayyyy 1
# @yongshwa 1
# notifs 1
# sound 11
# Selena's 1
# mel 1
# fifa 1
# @Mars_Sum41 1
# injure 1
# prevalent 1
# talaga 1
# @dailyteenwords 1
# @zaynsart 1
# FERN 1
# @AndrewFairbairn 1
# capcom 2
# @IzayaTheGod 1
# portrait 1
# diet 1
# Y 5
# striped 1
# #gamers 1
# pantes 1
# writes 1
# Jason 1
# ja 2
# taylor 1
# @RealLiamPaynePH 1
# thooo 1
# @radicalj 1
# Sit 1
# horrendously 1
# strap 1
# braids 1
# ape 1
# @pcy_rock 1
# noise 2
# Finnick's 1
# wants 8
# @ApparentlyShane 1
# lifeless 1
# Stella 1
# doesnt 1
# float 2
# #OnTheRoadAgain2015 1
# 7pm 1
# @HomeXpertsLeyla 1
# self 1
# @douglaswhates 1
# @VodafoneIrl 1
# WHYYYYYY 1
# ahahah 1
# GWS 1
# huvvft 1
# kInda 1
# closer 2
# @Danny_boym 1
# @seulgi_psv 1
# @honestfandom 1
# journey 1
# apps 1
# uploaded 1
# subj 1
# WATCHING 1
# Sweat 1
# Fab 1
# peregrines 1
# tau 1
# Currently 1
# https://t.co/BFslmBZOAh 1
# #nakamaforever 3
# @kaisoography 1
# @punkrockbgmouth 1
# @AnnaSaccone 1
# #AskFinnick 1
# jobee 1
# trop 2
# @Tyrese 1
# Australia's 1
# bae 8
# 300 3
# halaaaang 1
# Left 1
# [ 6
# welcome 4
# hopefully 9
# Biodiversity 1
# plssssssssssssssss 1
# #BlockJam 1
# @JackAndJackReal 2
# nu-uh 1
# people's 1
# Blame 1
# beers 1
# cinnamon 1
# ankles 1
# volume 1
# YA 3
# soak 1
# https://t.co/2uRT9ae8Px 1
# http://t.co/Oe5ID3cJIR 1
# #trade 1
# East 1
# naging 1
# @mrnhrn 1
# planning 3
# ffvi 1
# tf 2
# @iamsrk 2
# SEEKER 1
# Gusto 1
# @Earl_Wolf24 1
# #sexy 9
# Brb 1
# cheese 7
# Billionaires 1
# disney 1
# conference 2
# @xo_raaaaayyy_xo 1
# likes 4
# rolls 1
# @nambooti 1
# second 3
# @Glassyskyx 1
# diz 1
# mast 1
# pleasse 1
# counting 2
# rly 4
# CPM 1
# fast 5
# define 1
# #brasileirao 2
# @TreqEu 1
# @KookieAnda 1
# comics 3
# feel 91
# Wft 1
# SUNNY's 1
# Pic 1
# @RocketLeague 1
# Packing 1
# they 106
# eid 2
# goodies 1
# 2-0 1
# @wonwooo17 1
# jest 1
# towns 6
# #bad4thwin 3
# lagg 1
# goodness 1
# @margauxxemm 1
# @muscularpayne 2
# #sect 1
# @peanutbutler 1
# muchie 1
# hmmm 1
# Dog 2
# @FoooerSG 1
# @nirbananalrh 1
# @robbiemacalino 1
# YALL 1
# http://t.co/WbxjcwXiqF 1
# reece 1
# youre 6
# finding 5
# company 3
# @RoyalAlbertHall 1
# appreciate 1
# fainted 1
# race 1
# Dad 1
# mood-dump 1
# some 58

# %%
print(len(howmanywords))
# Out:
# 12545

# %%
allUsers = []

for line in open(file_location,"r"):
    js = json.loads(line.rstrip())
    user = js['user']['screen_name']
    
    allUsers.append(user)

# %%
len(allUsers)
# Out:
# 5000
